# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikeyahl/MS_analysis/blob/main/PunchTimeAnalysisLatest3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import numpy as np
import pandas as pd
from datetime import datetime,timedelta
import math

# %%
# Importing the excel
# !unzip punch_short.xlsx
dataset = pd.read_excel('punch_short.xlsx',parse_dates=['Date'],
    date_parser=lambda x: pd.to_datetime(x, format='%Y%m%d'))
dataset2=pd.read_excel('Master Data.xlsx')
dataset3=pd.read_excel('Shift_Timings.xlsx')
# Out:
# Archive:  punch_short.xlsx
# replace [Content_Types].xml? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: [Content_Types].xml
#   inflating: _rels/.rels
#   inflating: xl/workbook.xml
#   inflating: xl/_rels/workbook.xml.rels
#   inflating: xl/worksheets/sheet1.xml
#   inflating: xl/theme/theme1.xml
#   inflating: xl/styles.xml
#   inflating: xl/sharedStrings.xml
#   inflating: xl/externalLinks/externalLink1.xml
#   inflating: xl/connections.xml
#   inflating: xl/calcChain.xml
#   inflating: docProps/core.xml
#   inflating: docProps/app.xml
#   inflating: xl/externalLinks/_rels/externalLink1.xml.rels

# %%
#Renaming column name to a valid column name format as per python
dataset.rename(columns={'IN/OUT': 'IN_OUT'}, inplace=True)

# %%
#Droping rows that conatain 1 in 'IN_OUT' column
dataset=dataset[dataset.IN_OUT!=1]

# %%
dataset['Date'] = pd.to_datetime(dataset['Date'], errors='coerce')
# dataset3['date'] = pd.to_datetime(dataset3['date'], errors='coerce')

# %%
a1=str(dataset.iloc[0]['Date'])
a2=str(dataset.iloc[-1]['Date'])
d1 = datetime.strptime(a1[0:10], "%Y-%m-%d")
d2 = datetime.strptime(a2[0:10], "%Y-%m-%d")
date_diff = abs((d2 - d1).days)+1

# %%
#Calculating and appending Punch time difference for each employee with the corresponding E.Code into dataframe (l)
l_shift=[]
for i in range(len(dataset3)):
  x_=str(dataset3.iloc[i]['Start'])
  y_=str(dataset3.iloc[i]['End'])

  if len(x_)<=5:
    x_=x_.zfill(6)
  if len(y_)<=5:
    y_=y_.zfill(6)

  x_ = datetime.strptime(x_, "%H%M%S")
  x_.strftime("%I:%M %p")
  y_ = datetime.strptime(y_, "%H%M%S")
  y_.strftime("%I:%M %p")

  presentday = pd.to_datetime('20221001', errors='coerce')
  tomorrow = pd.to_datetime('20221002', errors='coerce')
  if dataset3.iloc[i]['End date']=='same':
    l_shift.append([datetime.combine(presentday, y_.time()) - datetime.combine(presentday, x_.time())])
  else:
    l_shift.append([datetime.combine(tomorrow, y_.time()) - datetime.combine(presentday, x_.time())])

# %%
#Calculating and appending Punch time difference for each employee with the corresponding E.Code into dataframe (l)
l=[]
for i in range(len(dataset)-1):
  j=i+1
  x=str(dataset.iloc[i]['Time'])
  y=str(dataset.iloc[j]['Time'])

  if len(x)<=5:
    x=x.zfill(6)
  if len(y)<=5:
    y=y.zfill(6)

  x = datetime.strptime(x, "%H%M%S")
  x.strftime("%I:%M %p")
  y = datetime.strptime(y, "%H%M%S")
  y.strftime("%I:%M %p")

  l.append([dataset.iloc[i]['E.Code'], dataset.iloc[i]['Date'].date(), dataset.iloc[i]['IN_OUT'], int(dataset.iloc[i]['Time']), datetime.combine(dataset.iloc[j]['Date'], y.time()) - datetime.combine(dataset.iloc[i]['Date'], x.time()),dataset.iloc[i]['Location']])  
  i=i+2

# %%
l
# Out:
# [[27,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82100,
#   datetime.timedelta(seconds=32820),
#   'Tapukara Plant 2F'],
#  [27,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172800,
#   datetime.timedelta(days=-1, seconds=53100),
#   'Tapukara Plant 2F'],
#  [48,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81300,
#   datetime.timedelta(seconds=33120),
#   'Head Office - Manesar'],
#  [48,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=53220),
#   'Head Office - Manesar'],
#  [49,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81200,
#   datetime.timedelta(seconds=36480),
#   'EBQ HO - Manesar'],
#  [49,
#   datetime.date(2022, 4, 20),
#   'P20',
#   182000,
#   datetime.timedelta(days=-1, seconds=50640),
#   'EBQ HO - Manesar'],
#  [72,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82400,
#   datetime.timedelta(seconds=35820),
#   'EBQ HO - Manesar'],
#  [72,
#   datetime.date(2022, 4, 20),
#   'P20',
#   182100,
#   datetime.timedelta(days=-1, seconds=49800),
#   'EBQ HO - Manesar'],
#  [80,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81100,
#   datetime.timedelta(seconds=43740),
#   'Narsapura Plant 3F'],
#  [80,
#   datetime.date(2022, 4, 20),
#   'P20',
#   202000,
#   datetime.timedelta(days=-1, seconds=43380),
#   'Narsapura Plant 3F'],
#  [87,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82300,
#   datetime.timedelta(seconds=33720),
#   'EBQ HO - Manesar'],
#  [87,
#   datetime.date(2022, 4, 20),
#   'P20',
#   174500,
#   datetime.timedelta(days=-1, seconds=51600),
#   'EBQ HO - Manesar'],
#  [88,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80500,
#   datetime.timedelta(seconds=34320),
#   'Manesar Plant 1F'],
#  [88,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173700,
#   datetime.timedelta(days=-1, seconds=52200),
#   'Manesar Plant 1F'],
#  [108,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80700,
#   datetime.timedelta(seconds=36720),
#   'EBQ HO - Manesar'],
#  [108,
#   datetime.date(2022, 4, 20),
#   'P20',
#   181900,
#   datetime.timedelta(days=-1, seconds=49680),
#   'EBQ HO - Manesar'],
#  [125,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80700,
#   datetime.timedelta(seconds=34080),
#   'Vithalapur Plant 4F'],
#  [125,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173500,
#   datetime.timedelta(days=-1, seconds=52920),
#   'Vithalapur Plant 4F'],
#  [126,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81700,
#   datetime.timedelta(seconds=32580),
#   'Vithalapur Plant 4F'],
#  [126,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172000,
#   datetime.timedelta(days=-1, seconds=46440),
#   'Vithalapur Plant 4F'],
#  [167,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [167,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=84060),
#   'Manesar Plant 1F'],
#  [168,
#   datetime.date(2022, 4, 20),
#   'P10',
#   144600,
#   datetime.timedelta(seconds=18960),
#   'Vithalapur Plant 4F'],
#  [168,
#   datetime.date(2022, 4, 20),
#   'P20',
#   200200,
#   datetime.timedelta(days=-1, seconds=44400),
#   'Vithalapur Plant 4F'],
#  [169,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82200,
#   datetime.timedelta(seconds=32820),
#   'Vithalapur Plant 4F'],
#  [169,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=78000),
#   'Vithalapur Plant 4F'],
#  [172,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [172,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=28020),
#   'Manesar Plant 1F'],
#  [174,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80100,
#   datetime.timedelta(seconds=34260),
#   'Manesar Plant 1F'],
#  [174,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173200,
#   datetime.timedelta(days=-1, seconds=51300),
#   'Manesar Plant 1F'],
#  [180,
#   datetime.date(2022, 4, 20),
#   'P10',
#   74700,
#   datetime.timedelta(seconds=33360),
#   'RO - Manesar'],
#  [180,
#   datetime.date(2022, 4, 20),
#   'P20',
#   170300,
#   datetime.timedelta(days=-1, seconds=45000),
#   'RO - Manesar'],
#  [181,
#   datetime.date(2022, 4, 20),
#   'P10',
#   53300,
#   datetime.timedelta(seconds=33300),
#   'Narsapura Plant 3F'],
#  [181,
#   datetime.date(2022, 4, 20),
#   'P20',
#   144800,
#   datetime.timedelta(seconds=1080),
#   'Narsapura Plant 3F'],
#  [183,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [183,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [186,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150700,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [186,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=21660),
#   'Manesar Plant 1F'],
#  [190,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [190,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(seconds=29400),
#   'Manesar Plant 1F'],
#  [191,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233200,
#   datetime.timedelta(seconds=26340),
#   'Manesar Plant 1F'],
#  [191,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65100,
#   datetime.timedelta(days=-1, seconds=5520),
#   'Manesar Plant 1F'],
#  [196,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82300,
#   datetime.timedelta(seconds=32580),
#   'Vithalapur Plant 4F'],
#  [196,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172600,
#   datetime.timedelta(days=-1, seconds=77940),
#   'Vithalapur Plant 4F'],
#  [198,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [198,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=51720),
#   'Manesar Plant 1F'],
#  [201,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143400,
#   datetime.timedelta(seconds=33240),
#   'Tapukara Plant 2F'],
#  [201,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234800,
#   datetime.timedelta(days=-1, seconds=54960),
#   'Tapukara Plant 2F'],
#  [202,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150400,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [202,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=21780),
#   'Manesar Plant 1F'],
#  [205,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [205,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=83520),
#   'Manesar Plant 1F'],
#  [206,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143600,
#   datetime.timedelta(seconds=33060),
#   'Tapukara Plant 2F'],
#  [206,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234700,
#   datetime.timedelta(days=-1, seconds=31080),
#   'Tapukara Plant 2F'],
#  [208,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82500,
#   datetime.timedelta(seconds=32640),
#   'Vithalapur Plant 4F'],
#  [208,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=44880),
#   'Vithalapur Plant 4F'],
#  [209,
#   datetime.date(2022, 4, 20),
#   'P10',
#   55700,
#   datetime.timedelta(seconds=32640),
#   'Vithalapur Plant 4F'],
#  [209,
#   datetime.date(2022, 4, 20),
#   'P20',
#   150100,
#   datetime.timedelta(days=-1, seconds=54780),
#   'Vithalapur Plant 4F'],
#  [210,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [210,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=60180),
#   'Manesar Plant 1F'],
#  [211,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80400,
#   datetime.timedelta(seconds=34020),
#   'Vithalapur Plant 4F'],
#  [211,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173100,
#   datetime.timedelta(days=-1, seconds=45720),
#   'Vithalapur Plant 4F'],
#  [214,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [214,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=60300),
#   'Manesar Plant 1F'],
#  [221,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80900,
#   datetime.timedelta(seconds=33300),
#   'Manesar Plant 1F'],
#  [221,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=57900),
#   'Manesar Plant 1F'],
#  [224,
#   datetime.date(2022, 4, 20),
#   'P10',
#   92900,
#   datetime.timedelta(seconds=33420),
#   'Head Office - Manesar'],
#  [224,
#   datetime.date(2022, 4, 20),
#   'P20',
#   184600,
#   datetime.timedelta(days=-1, seconds=71760),
#   'Head Office - Manesar'],
#  [240,
#   datetime.date(2022, 4, 20),
#   'P10',
#   144200,
#   datetime.timedelta(seconds=32340),
#   'Vithalapur Plant 4F'],
#  [240,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234100,
#   datetime.timedelta(days=-1, seconds=52980),
#   'Vithalapur Plant 4F'],
#  [245,
#   datetime.date(2022, 4, 20),
#   'P10',
#   142400,
#   datetime.timedelta(seconds=33660),
#   'Vithalapur Plant 4F'],
#  [245,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234500,
#   datetime.timedelta(days=-1, seconds=30300),
#   'Vithalapur Plant 4F'],
#  [247,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81000,
#   datetime.timedelta(seconds=33540),
#   'Tapukara Plant 2F'],
#  [247,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=45960),
#   'Tapukara Plant 2F'],
#  [251,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [251,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=50640),
#   'Manesar Plant 1F'],
#  [252,
#   datetime.date(2022, 4, 20),
#   'P10',
#   53100,
#   datetime.timedelta(seconds=34020),
#   'Vithalapur Plant 4F'],
#  [252,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145800,
#   datetime.timedelta(seconds=30840),
#   'Vithalapur Plant 4F'],
#  [253,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233200,
#   datetime.timedelta(seconds=26700),
#   'Manesar Plant 1F'],
#  [253,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65700,
#   datetime.timedelta(days=-1, seconds=5280),
#   'Manesar Plant 1F'],
#  [257,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82500,
#   datetime.timedelta(seconds=26220),
#   'Manesar Plant 1F'],
#  [257,
#   datetime.date(2022, 4, 20),
#   'P20',
#   154200,
#   datetime.timedelta(days=-1, seconds=53040),
#   'Manesar Plant 1F'],
#  [262,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62600,
#   datetime.timedelta(seconds=32220),
#   'Manesar Plant 1F'],
#  [262,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=59460),
#   'Manesar Plant 1F'],
#  [267,
#   datetime.date(2022, 4, 20),
#   'P10',
#   75400,
#   datetime.timedelta(seconds=39300),
#   'Narsapura Plant 3F'],
#  [267,
#   datetime.date(2022, 4, 20),
#   'P20',
#   184900,
#   datetime.timedelta(days=-1, seconds=48360),
#   'Narsapura Plant 3F'],
#  [275,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81500,
#   datetime.timedelta(seconds=41160),
#   'EBQ HO - Manesar'],
#  [275,
#   datetime.date(2022, 4, 20),
#   'P20',
#   194100,
#   datetime.timedelta(days=-1, seconds=38100),
#   'EBQ HO - Manesar'],
#  [280,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61600,
#   datetime.timedelta(seconds=32700),
#   'Vithalapur Plant 4F'],
#  [280,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53820),
#   'Vithalapur Plant 4F'],
#  [281,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [281,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=60480),
#   'Manesar Plant 1F'],
#  [285,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81100,
#   datetime.timedelta(seconds=33420),
#   'Vithalapur Plant 4F'],
#  [285,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172800,
#   datetime.timedelta(days=-1, seconds=75720),
#   'Vithalapur Plant 4F'],
#  [287,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143000,
#   datetime.timedelta(seconds=33480),
#   'Tapukara Plant 2F'],
#  [287,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234800,
#   datetime.timedelta(days=-1, seconds=31320),
#   'Tapukara Plant 2F'],
#  [288,
#   datetime.date(2022, 4, 20),
#   'P10',
#   83000,
#   datetime.timedelta(seconds=32100),
#   'Vithalapur Plant 4F'],
#  [288,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=53100),
#   'Vithalapur Plant 4F'],
#  [292,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81000,
#   datetime.timedelta(seconds=33600),
#   'Tapukara Plant 2F'],
#  [292,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173000,
#   datetime.timedelta(days=-1, seconds=77460),
#   'Tapukara Plant 2F'],
#  [294,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [294,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=52320),
#   'Manesar Plant 1F'],
#  [296,
#   datetime.date(2022, 4, 20),
#   'P10',
#   144600,
#   datetime.timedelta(seconds=25440),
#   'Tapukara Plant 2F'],
#  [296,
#   datetime.date(2022, 4, 20),
#   'P20',
#   215000,
#   datetime.timedelta(days=-1, seconds=30240),
#   'Tapukara Plant 2F'],
#  [297,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [297,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=60960),
#   'Manesar Plant 1F'],
#  [298,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82100,
#   datetime.timedelta(seconds=32640),
#   'Vithalapur Plant 4F'],
#  [298,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=46200),
#   'Vithalapur Plant 4F'],
#  [300,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [300,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(seconds=29880),
#   'Manesar Plant 1F'],
#  [301,
#   datetime.date(2022, 4, 20),
#   'P10',
#   234000,
#   datetime.timedelta(seconds=25860),
#   'Manesar Plant 1F'],
#  [301,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65100,
#   datetime.timedelta(days=-2, seconds=84360),
#   'Manesar Plant 1F'],
#  [302,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [302,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=60720),
#   'Manesar Plant 1F'],
#  [303,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81700,
#   datetime.timedelta(seconds=47640),
#   'Vithalapur Plant 4F'],
#  [303,
#   datetime.date(2022, 4, 20),
#   'P20',
#   213100,
#   datetime.timedelta(days=-1, seconds=31680),
#   'Vithalapur Plant 4F'],
#  [306,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [306,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=85800),
#   'Manesar Plant 1F'],
#  [317,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151200,
#   datetime.timedelta(seconds=32400),
#   'Manesar Plant 1F'],
#  [317,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=22020),
#   'Manesar Plant 1F'],
#  [318,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [318,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=85980),
#   'Manesar Plant 1F'],
#  [320,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151300,
#   datetime.timedelta(seconds=32280),
#   'Manesar Plant 1F'],
#  [320,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=28440),
#   'Manesar Plant 1F'],
#  [322,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80500,
#   datetime.timedelta(seconds=34020),
#   'Narsapura Plant 3F'],
#  [322,
#   datetime.date(2022, 4, 20),
#   'P20',
#   173200,
#   datetime.timedelta(days=-1, seconds=45720),
#   'Narsapura Plant 3F'],
#  [334,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [334,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [336,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [336,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=53280),
#   'Manesar Plant 1F'],
#  [339,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [339,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=61020),
#   'Manesar Plant 1F'],
#  [345,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82100,
#   datetime.timedelta(seconds=32640),
#   'Tapukara Plant 2F'],
#  [345,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(seconds=22020),
#   'Tapukara Plant 2F'],
#  [347,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233200,
#   datetime.timedelta(seconds=26460),
#   'Manesar Plant 1F'],
#  [347,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65300,
#   datetime.timedelta(days=-1, seconds=26160),
#   'Manesar Plant 1F'],
#  [352,
#   datetime.date(2022, 4, 20),
#   'P10',
#   140900,
#   datetime.timedelta(seconds=42060),
#   'Narsapura Plant 3F'],
#  [352,
#   datetime.date(2022, 4, 21),
#   'P20',
#   15000,
#   datetime.timedelta(days=-1, seconds=16080),
#   'Narsapura Plant 3F'],
#  [361,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [361,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152900,
#   datetime.timedelta(days=-1, seconds=58620),
#   'Manesar Plant 1F'],
#  [368,
#   datetime.date(2022, 4, 20),
#   'P10',
#   74600,
#   datetime.timedelta(seconds=44220),
#   'Narsapura Plant 3F'],
#  [368,
#   datetime.date(2022, 4, 20),
#   'P20',
#   200300,
#   datetime.timedelta(days=-1, seconds=35640),
#   'Narsapura Plant 3F'],
#  [377,
#   datetime.date(2022, 4, 20),
#   'P10',
#   55700,
#   datetime.timedelta(seconds=32400),
#   'Tapukara Plant 2F'],
#  [377,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145700,
#   datetime.timedelta(days=-1, seconds=85140),
#   'Tapukara Plant 2F'],
#  [378,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143600,
#   datetime.timedelta(seconds=33000),
#   'Tapukara Plant 2F'],
#  [378,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234600,
#   datetime.timedelta(days=-1, seconds=55440),
#   'Tapukara Plant 2F'],
#  [379,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151000,
#   datetime.timedelta(seconds=32400),
#   'Manesar Plant 1F'],
#  [379,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=29280),
#   'Manesar Plant 1F'],
#  [381,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81800,
#   datetime.timedelta(seconds=33000),
#   'Tapukara Plant 2F'],
#  [381,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172800,
#   datetime.timedelta(days=-1, seconds=46260),
#   'Tapukara Plant 2F'],
#  [382,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [382,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=53520),
#   'Manesar Plant 1F'],
#  [385,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [385,
#   datetime.date(2022, 4, 20),
#   'P20',
#   153000,
#   datetime.timedelta(days=-1, seconds=59220),
#   'Manesar Plant 1F'],
#  [386,
#   datetime.date(2022, 4, 20),
#   'P10',
#   75700,
#   datetime.timedelta(seconds=34200),
#   'Narsapura Plant 3F'],
#  [386,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172700,
#   datetime.timedelta(days=-1, seconds=78120),
#   'Narsapura Plant 3F'],
#  [388,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [388,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=44040),
#   'Manesar Plant 1F'],
#  [390,
#   datetime.date(2022, 4, 20),
#   'P10',
#   122600,
#   datetime.timedelta(seconds=18000),
#   'Tapukara Plant 2F'],
#  [390,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172600,
#   datetime.timedelta(days=-1, seconds=52740),
#   'Tapukara Plant 2F'],
#  [392,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80500,
#   datetime.timedelta(seconds=33720),
#   'Narsapura Plant 3F'],
#  [392,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172700,
#   datetime.timedelta(days=-1, seconds=45900),
#   'Narsapura Plant 3F'],
#  [395,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61200,
#   datetime.timedelta(seconds=33300),
#   'Manesar Plant 1F'],
#  [395,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=53040),
#   'Manesar Plant 1F'],
#  [396,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [396,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [398,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [398,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=85260),
#   'Manesar Plant 1F'],
#  [399,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [399,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=22260),
#   'Manesar Plant 1F'],
#  [402,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62200,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [402,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=85920),
#   'Manesar Plant 1F'],
#  [405,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151600,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [405,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [419,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [419,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=28560),
#   'Manesar Plant 1F'],
#  [423,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80600,
#   datetime.timedelta(seconds=33780),
#   'Narsapura Plant 3F'],
#  [423,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=43260),
#   'Narsapura Plant 3F'],
#  [424,
#   datetime.date(2022, 4, 20),
#   'P10',
#   53000,
#   datetime.timedelta(seconds=33600),
#   'Narsapura Plant 3F'],
#  [424,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145000,
#   datetime.timedelta(seconds=900),
#   'Narsapura Plant 3F'],
#  [426,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [426,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=28200),
#   'Manesar Plant 1F'],
#  [428,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80100,
#   datetime.timedelta(seconds=33900),
#   'Narsapura Plant 3F'],
#  [428,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172600,
#   datetime.timedelta(days=-1, seconds=52740),
#   'Narsapura Plant 3F'],
#  [429,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80500,
#   datetime.timedelta(seconds=44100),
#   'Narsapura Plant 3F'],
#  [429,
#   datetime.date(2022, 4, 20),
#   'P20',
#   202000,
#   datetime.timedelta(days=-1, seconds=43680),
#   'Narsapura Plant 3F'],
#  [434,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82800,
#   datetime.timedelta(seconds=32340),
#   'Manesar Plant 1F'],
#  [434,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172700,
#   datetime.timedelta(days=-1, seconds=46200),
#   'Manesar Plant 1F'],
#  [448,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [448,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53100),
#   'Manesar Plant 1F'],
#  [449,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61000,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [449,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=85740),
#   'Manesar Plant 1F'],
#  [450,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=15840),
#   'Manesar Plant 1F'],
#  [450,
#   datetime.date(2022, 4, 20),
#   'P20',
#   193300,
#   datetime.timedelta(days=-1, seconds=45780),
#   'Manesar Plant 1F'],
#  [452,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81600,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [452,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=53340),
#   'Manesar Plant 1F'],
#  [453,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81300,
#   datetime.timedelta(seconds=27120),
#   'Manesar Plant 1F'],
#  [453,
#   datetime.date(2022, 4, 20),
#   'P20',
#   154500,
#   datetime.timedelta(days=-1, seconds=83700),
#   'Manesar Plant 1F'],
#  [456,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150000,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [456,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=21600),
#   'Manesar Plant 1F'],
#  [458,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [458,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=85200),
#   'Manesar Plant 1F'],
#  [459,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150300,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [459,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=22140),
#   'Manesar Plant 1F'],
#  [460,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [460,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=50820),
#   'Manesar Plant 1F'],
#  [465,
#   datetime.date(2022, 4, 20),
#   'P10',
#   53400,
#   datetime.timedelta(seconds=33480),
#   'Narsapura Plant 3F'],
#  [465,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145200,
#   datetime.timedelta(seconds=1020),
#   'Narsapura Plant 3F'],
#  [466,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [466,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=29220),
#   'Manesar Plant 1F'],
#  [468,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81700,
#   datetime.timedelta(seconds=33000),
#   'Vithalapur Plant 4F'],
#  [468,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172700,
#   datetime.timedelta(days=-1, seconds=46320),
#   'Vithalapur Plant 4F'],
#  [471,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [471,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=85560),
#   'Manesar Plant 1F'],
#  [474,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151200,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [474,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1500,
#   datetime.timedelta(days=-1, seconds=19740),
#   'Manesar Plant 1F'],
#  [477,
#   datetime.date(2022, 4, 20),
#   'P10',
#   54400,
#   datetime.timedelta(seconds=33300),
#   'Tapukara Plant 2F'],
#  [477,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145900,
#   datetime.timedelta(days=-1, seconds=62400),
#   'Tapukara Plant 2F'],
#  [486,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81900,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [486,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=46380),
#   'Manesar Plant 1F'],
#  [487,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [487,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53760),
#   'Manesar Plant 1F'],
#  [488,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [488,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53760),
#   'Manesar Plant 1F'],
#  [489,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [489,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=85200),
#   'Manesar Plant 1F'],
#  [491,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [491,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [492,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [492,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=28800),
#   'Manesar Plant 1F'],
#  [493,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81000,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [493,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172200,
#   datetime.timedelta(days=-1, seconds=46320),
#   'Manesar Plant 1F'],
#  [494,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32940),
#   'Vithalapur Plant 4F'],
#  [494,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53460),
#   'Vithalapur Plant 4F'],
#  [499,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [499,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(seconds=30840),
#   'Manesar Plant 1F'],
#  [501,
#   datetime.date(2022, 4, 20),
#   'P10',
#   235900,
#   datetime.timedelta(seconds=24780),
#   'Manesar Plant 1F'],
#  [501,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65200,
#   datetime.timedelta(days=-1, seconds=4740),
#   'Manesar Plant 1F'],
#  [502,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81100,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [502,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=78600),
#   'Manesar Plant 1F'],
#  [504,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151400,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [504,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=52500),
#   'Manesar Plant 1F'],
#  [506,
#   datetime.date(2022, 4, 20),
#   'P10',
#   144500,
#   datetime.timedelta(seconds=32520),
#   'Tapukara Plant 2F'],
#  [506,
#   datetime.date(2022, 4, 20),
#   'P20',
#   234700,
#   datetime.timedelta(days=-1, seconds=23520),
#   'Tapukara Plant 2F'],
#  [508,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [508,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=54420),
#   'Manesar Plant 1F'],
#  [509,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62900,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [509,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53400),
#   'Manesar Plant 1F'],
#  [510,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [510,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53820),
#   'Manesar Plant 1F'],
#  [511,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62000,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [511,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53700),
#   'Manesar Plant 1F'],
#  [512,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [512,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=61140),
#   'Manesar Plant 1F'],
#  [518,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82200,
#   datetime.timedelta(seconds=32520),
#   'EBQ HO - Manesar'],
#  [518,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=46020),
#   'EBQ HO - Manesar'],
#  [519,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [519,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=85620),
#   'Manesar Plant 1F'],
#  [524,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151000,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [524,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=29160),
#   'Manesar Plant 1F'],
#  [525,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82000,
#   datetime.timedelta(seconds=29580),
#   'Tapukara Plant 2F'],
#  [525,
#   datetime.date(2022, 4, 20),
#   'P20',
#   163300,
#   datetime.timedelta(days=-1, seconds=49380),
#   'Tapukara Plant 2F'],
#  [526,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61600,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [526,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=60840),
#   'Manesar Plant 1F'],
#  [528,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81600,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [528,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=53700),
#   'Manesar Plant 1F'],
#  [529,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82000,
#   datetime.timedelta(seconds=32700),
#   'Vithalapur Plant 4F'],
#  [529,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=53040),
#   'Vithalapur Plant 4F'],
#  [532,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80900,
#   datetime.timedelta(seconds=33300),
#   'EBQ HO - Manesar'],
#  [532,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=78240),
#   'EBQ HO - Manesar'],
#  [533,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150800,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [533,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=21540),
#   'Manesar Plant 1F'],
#  [538,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=33300),
#   'Manesar Plant 1F'],
#  [538,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=85320),
#   'Manesar Plant 1F'],
#  [543,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150800,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [543,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=20040),
#   'Manesar Plant 1F'],
#  [545,
#   datetime.date(2022, 4, 20),
#   'P10',
#   54700,
#   datetime.timedelta(seconds=34920),
#   'Manesar Plant 1F'],
#  [545,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152900,
#   datetime.timedelta(days=-1, seconds=84720),
#   'Manesar Plant 1F'],
#  [547,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [547,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=53820),
#   'Manesar Plant 1F'],
#  [551,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150700,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [551,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=21420),
#   'Manesar Plant 1F'],
#  [554,
#   datetime.date(2022, 4, 20),
#   'P10',
#   60800,
#   datetime.timedelta(seconds=33480),
#   'Manesar Plant 1F'],
#  [554,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=53280),
#   'Manesar Plant 1F'],
#  [555,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [555,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=85200),
#   'Manesar Plant 1F'],
#  [557,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [557,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21780),
#   'Manesar Plant 1F'],
#  [558,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [558,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=54060),
#   'Manesar Plant 1F'],
#  [560,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62200,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [560,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=85500),
#   'Manesar Plant 1F'],
#  [562,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150800,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [562,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=51360),
#   'Manesar Plant 1F'],
#  [565,
#   datetime.date(2022, 4, 20),
#   'P10',
#   142700,
#   datetime.timedelta(seconds=20400),
#   'Vithalapur Plant 4F'],
#  [565,
#   datetime.date(2022, 4, 20),
#   'P20',
#   200700,
#   datetime.timedelta(days=-1, seconds=68400),
#   'Vithalapur Plant 4F'],
#  [567,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150700,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [567,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1500,
#   datetime.timedelta(days=-1, seconds=20280),
#   'Manesar Plant 1F'],
#  [570,
#   datetime.date(2022, 4, 20),
#   'P10',
#   55300,
#   datetime.timedelta(seconds=32700),
#   'Vithalapur Plant 4F'],
#  [570,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145800,
#   datetime.timedelta(days=-1, seconds=55020),
#   'Vithalapur Plant 4F'],
#  [580,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [580,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=61560),
#   'Manesar Plant 1F'],
#  [581,
#   datetime.date(2022, 4, 20),
#   'P10',
#   83100,
#   datetime.timedelta(seconds=31920),
#   'Manesar Plant 1F'],
#  [581,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172300,
#   datetime.timedelta(days=-1, seconds=77820),
#   'Manesar Plant 1F'],
#  [585,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150000,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [585,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=21900),
#   'Manesar Plant 1F'],
#  [589,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [589,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=85380),
#   'Manesar Plant 1F'],
#  [590,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150400,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [590,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21780),
#   'Manesar Plant 1F'],
#  [592,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [592,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(seconds=29280),
#   'Manesar Plant 1F'],
#  [597,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233300,
#   datetime.timedelta(seconds=26520),
#   'Manesar Plant 1F'],
#  [597,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65500,
#   datetime.timedelta(days=-1, seconds=4560),
#   'Manesar Plant 1F'],
#  [599,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81100,
#   datetime.timedelta(seconds=43320),
#   'Narsapura Plant 3F'],
#  [599,
#   datetime.date(2022, 4, 20),
#   'P20',
#   201300,
#   datetime.timedelta(days=-1, seconds=67680),
#   'Narsapura Plant 3F'],
#  [605,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33300),
#   'Manesar Plant 1F'],
#  [605,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1600,
#   datetime.timedelta(days=-1, seconds=81480),
#   'Manesar Plant 1F'],
#  [613,
#   datetime.date(2022, 4, 20),
#   'P10',
#   225400,
#   datetime.timedelta(seconds=27060),
#   'Tapukara Plant 2F'],
#  [613,
#   datetime.date(2022, 4, 21),
#   'P20',
#   62500,
#   datetime.timedelta(days=-2, seconds=85800),
#   'Tapukara Plant 2F'],
#  [622,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [622,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53760),
#   'Manesar Plant 1F'],
#  [623,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [623,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53520),
#   'Manesar Plant 1F'],
#  [629,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [629,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=51660),
#   'Manesar Plant 1F'],
#  [630,
#   datetime.date(2022, 4, 20),
#   'P10',
#   54100,
#   datetime.timedelta(seconds=33480),
#   'Tapukara Plant 2F'],
#  [630,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145900,
#   datetime.timedelta(seconds=60),
#   'Tapukara Plant 2F'],
#  [631,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150000,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [631,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=21780),
#   'Manesar Plant 1F'],
#  [633,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61600,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [633,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=53280),
#   'Manesar Plant 1F'],
#  [637,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [637,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=84840),
#   'Manesar Plant 1F'],
#  [639,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [639,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1500,
#   datetime.timedelta(days=-1, seconds=21360),
#   'Manesar Plant 1F'],
#  [640,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=40380),
#   'Manesar Plant 1F'],
#  [640,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172400,
#   datetime.timedelta(days=-1, seconds=79740),
#   'Manesar Plant 1F'],
#  [641,
#   datetime.date(2022, 4, 20),
#   'P10',
#   153300,
#   datetime.timedelta(seconds=31260),
#   'Manesar Plant 1F'],
#  [641,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [642,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150700,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [642,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1500,
#   datetime.timedelta(days=-1, seconds=22320),
#   'Manesar Plant 1F'],
#  [643,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62700,
#   datetime.timedelta(seconds=32100),
#   'Manesar Plant 1F'],
#  [643,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(seconds=29760),
#   'Manesar Plant 1F'],
#  [645,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233800,
#   datetime.timedelta(seconds=25920),
#   'Manesar Plant 1F'],
#  [645,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65000,
#   datetime.timedelta(days=-2, seconds=84180),
#   'Manesar Plant 1F'],
#  [646,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [646,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=59940),
#   'Manesar Plant 1F'],
#  [647,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80200,
#   datetime.timedelta(seconds=34020),
#   'Narsapura Plant 3F'],
#  [647,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=78180),
#   'Narsapura Plant 3F'],
#  [648,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151200,
#   datetime.timedelta(seconds=32280),
#   'Manesar Plant 1F'],
#  [648,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=54060),
#   'Manesar Plant 1F'],
#  [650,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151100,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [650,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=53760),
#   'Manesar Plant 1F'],
#  [652,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [652,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21660),
#   'Manesar Plant 1F'],
#  [654,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [654,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=84900),
#   'Manesar Plant 1F'],
#  [655,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150000,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [655,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=54180),
#   'Manesar Plant 1F'],
#  [656,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151400,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [656,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21840),
#   'Manesar Plant 1F'],
#  [657,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [657,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=86100),
#   'Manesar Plant 1F'],
#  [660,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151700,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [660,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=21300),
#   'Manesar Plant 1F'],
#  [661,
#   datetime.date(2022, 4, 20),
#   'P10',
#   60800,
#   datetime.timedelta(seconds=33420),
#   'Manesar Plant 1F'],
#  [661,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53340),
#   'Manesar Plant 1F'],
#  [662,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [662,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53940),
#   'Manesar Plant 1F'],
#  [663,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62400,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [663,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(days=-1, seconds=85620),
#   'Manesar Plant 1F'],
#  [665,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151300,
#   datetime.timedelta(seconds=32400),
#   'Manesar Plant 1F'],
#  [665,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=53280),
#   'Manesar Plant 1F'],
#  [667,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [667,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=21720),
#   'Manesar Plant 1F'],
#  [668,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [668,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=53460),
#   'Manesar Plant 1F'],
#  [671,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=56160),
#   'Manesar Plant 1F'],
#  [671,
#   datetime.date(2022, 4, 20),
#   'P20',
#   215400,
#   datetime.timedelta(days=-1, seconds=61860),
#   'Manesar Plant 1F'],
#  [672,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [672,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=84480),
#   'Manesar Plant 1F'],
#  [673,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233800,
#   datetime.timedelta(seconds=26040),
#   'Manesar Plant 1F'],
#  [673,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65200,
#   datetime.timedelta(days=-2, seconds=84360),
#   'Manesar Plant 1F'],
#  [675,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=25320),
#   'Manesar Plant 1F'],
#  [675,
#   datetime.date(2022, 4, 20),
#   'P20',
#   132000,
#   datetime.timedelta(seconds=6060),
#   'Manesar Plant 1F'],
#  [676,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [676,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=28800),
#   'Manesar Plant 1F'],
#  [677,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81100,
#   datetime.timedelta(seconds=33480),
#   'Tapukara Plant 2F'],
#  [677,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172900,
#   datetime.timedelta(days=-1, seconds=52620),
#   'Tapukara Plant 2F'],
#  [678,
#   datetime.date(2022, 4, 20),
#   'P10',
#   80600,
#   datetime.timedelta(seconds=33540),
#   'Manesar Plant 1F'],
#  [678,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=46080),
#   'Manesar Plant 1F'],
#  [683,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [683,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [684,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33060),
#   'Manesar Plant 1F'],
#  [684,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=85500),
#   'Manesar Plant 1F'],
#  [688,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151000,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [688,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1500,
#   datetime.timedelta(days=-1, seconds=54120),
#   'Manesar Plant 1F'],
#  [691,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151700,
#   datetime.timedelta(seconds=32100),
#   'Manesar Plant 1F'],
#  [691,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
# ...
#   'Vithalapur Plant 4F'],
#  [1234,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151400,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [1234,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=23820),
#   'Manesar Plant 1F'],
#  [1235,
#   datetime.date(2022, 4, 20),
#   'P10',
#   64700,
#   datetime.timedelta(seconds=30840),
#   'Manesar Plant 1F'],
#  [1235,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53280),
#   'Manesar Plant 1F'],
#  [1238,
#   datetime.date(2022, 4, 20),
#   'P10',
#   60900,
#   datetime.timedelta(seconds=33360),
#   'Manesar Plant 1F'],
#  [1238,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=85860),
#   'Manesar Plant 1F'],
#  [1239,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151600,
#   datetime.timedelta(seconds=32040),
#   'Manesar Plant 1F'],
#  [1239,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=84000),
#   'Manesar Plant 1F'],
#  [1240,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233000,
#   datetime.timedelta(seconds=26520),
#   'Manesar Plant 1F'],
#  [1240,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65200,
#   datetime.timedelta(days=-1, seconds=29700),
#   'Manesar Plant 1F'],
#  [1246,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150700,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [1246,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=53820),
#   'Manesar Plant 1F'],
#  [1248,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151000,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [1248,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=83460),
#   'Manesar Plant 1F'],
#  [1249,
#   datetime.date(2022, 4, 20),
#   'P10',
#   232300,
#   datetime.timedelta(seconds=26940),
#   'Manesar Plant 1F'],
#  [1249,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65200,
#   datetime.timedelta(days=-2, seconds=84600),
#   'Manesar Plant 1F'],
#  [1250,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62200,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1250,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152600,
#   datetime.timedelta(seconds=29640),
#   'Manesar Plant 1F'],
#  [1259,
#   datetime.date(2022, 4, 20),
#   'P10',
#   234000,
#   datetime.timedelta(seconds=26100),
#   'Manesar Plant 1F'],
#  [1259,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65500,
#   datetime.timedelta(days=-1, seconds=29700),
#   'Manesar Plant 1F'],
#  [1260,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151000,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [1260,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=21720),
#   'Manesar Plant 1F'],
#  [1264,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [1264,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(seconds=28920),
#   'Manesar Plant 1F'],
#  [1265,
#   datetime.date(2022, 4, 20),
#   'P10',
#   232400,
#   datetime.timedelta(seconds=26760),
#   'Manesar Plant 1F'],
#  [1265,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65000,
#   datetime.timedelta(days=-1, seconds=29940),
#   'Manesar Plant 1F'],
#  [1267,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [1267,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=53880),
#   'Manesar Plant 1F'],
#  [1269,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150800,
#   datetime.timedelta(seconds=32700),
#   'Manesar Plant 1F'],
#  [1269,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=22020),
#   'Manesar Plant 1F'],
#  [1270,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62000,
#   datetime.timedelta(seconds=32580),
#   'Manesar Plant 1F'],
#  [1270,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=53880),
#   'Manesar Plant 1F'],
#  [1271,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62100,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1271,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=85080),
#   'Manesar Plant 1F'],
#  [1273,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150300,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [1273,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21720),
#   'Manesar Plant 1F'],
#  [1274,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61200,
#   datetime.timedelta(seconds=33900),
#   'Manesar Plant 1F'],
#  [1274,
#   datetime.date(2022, 4, 20),
#   'P20',
#   153700,
#   datetime.timedelta(days=-1, seconds=84480),
#   'Manesar Plant 1F'],
#  [1275,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [1275,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=55260),
#   'Manesar Plant 1F'],
#  [1276,
#   datetime.date(2022, 4, 20),
#   'P10',
#   153200,
#   datetime.timedelta(seconds=31140),
#   'Manesar Plant 1F'],
#  [1276,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=21840),
#   'Manesar Plant 1F'],
#  [1277,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [1277,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=53460),
#   'Manesar Plant 1F'],
#  [1278,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [1278,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=54300),
#   'Manesar Plant 1F'],
#  [1279,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62700,
#   datetime.timedelta(seconds=32400),
#   'Manesar Plant 1F'],
#  [1279,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152700,
#   datetime.timedelta(days=-1, seconds=85500),
#   'Manesar Plant 1F'],
#  [1280,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151200,
#   datetime.timedelta(seconds=32280),
#   'Manesar Plant 1F'],
#  [1280,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=54360),
#   'Manesar Plant 1F'],
#  [1282,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151600,
#   datetime.timedelta(seconds=32040),
#   'Manesar Plant 1F'],
#  [1282,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21840),
#   'Manesar Plant 1F'],
#  [1285,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [1285,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152800,
#   datetime.timedelta(days=-1, seconds=85260),
#   'Manesar Plant 1F'],
#  [1288,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [1288,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=22140),
#   'Manesar Plant 1F'],
#  [1290,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1290,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=85500),
#   'Manesar Plant 1F'],
#  [1291,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150800,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [1291,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1400,
#   datetime.timedelta(days=-1, seconds=54840),
#   'Manesar Plant 1F'],
#  [1292,
#   datetime.date(2022, 4, 20),
#   'P10',
#   152800,
#   datetime.timedelta(seconds=31500),
#   'Manesar Plant 1F'],
#  [1292,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=29400),
#   'Manesar Plant 1F'],
#  [1295,
#   datetime.date(2022, 4, 20),
#   'P10',
#   82300,
#   datetime.timedelta(seconds=32580),
#   'Vithalapur Plant 4F'],
#  [1295,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172600,
#   datetime.timedelta(days=-1, seconds=46020),
#   'Vithalapur Plant 4F'],
#  [1301,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=33300),
#   'Manesar Plant 1F'],
#  [1301,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152800,
#   datetime.timedelta(days=-1, seconds=85020),
#   'Manesar Plant 1F'],
#  [1303,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150500,
#   datetime.timedelta(seconds=32820),
#   'Manesar Plant 1F'],
#  [1303,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=84360),
#   'Manesar Plant 1F'],
#  [1305,
#   datetime.date(2022, 4, 20),
#   'P10',
#   233800,
#   datetime.timedelta(seconds=26100),
#   'Manesar Plant 1F'],
#  [1305,
#   datetime.date(2022, 4, 21),
#   'P20',
#   65300,
#   datetime.timedelta(days=-2, seconds=84060),
#   'Manesar Plant 1F'],
#  [1306,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [1306,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152300,
#   datetime.timedelta(days=-1, seconds=85920),
#   'Manesar Plant 1F'],
#  [1307,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151500,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [1307,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=19620),
#   'Manesar Plant 1F'],
#  [1315,
#   datetime.date(2022, 4, 20),
#   'P10',
#   53800,
#   datetime.timedelta(seconds=33180),
#   'Vithalapur Plant 4F'],
#  [1315,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145100,
#   datetime.timedelta(seconds=600),
#   'Vithalapur Plant 4F'],
#  [1319,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150100,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [1319,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1100,
#   datetime.timedelta(days=-1, seconds=55260),
#   'Manesar Plant 1F'],
#  [1320,
#   datetime.date(2022, 4, 20),
#   'P10',
#   153200,
#   datetime.timedelta(seconds=31200),
#   'Manesar Plant 1F'],
#  [1320,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=21840),
#   'Manesar Plant 1F'],
#  [1322,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61600,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [1322,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=85620),
#   'Manesar Plant 1F'],
#  [1323,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150900,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [1323,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=21780),
#   'Manesar Plant 1F'],
#  [1324,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61300,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [1324,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53580),
#   'Manesar Plant 1F'],
#  [1326,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61400,
#   datetime.timedelta(seconds=32880),
#   'Manesar Plant 1F'],
#  [1326,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=85440),
#   'Manesar Plant 1F'],
#  [1331,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32760),
#   'Manesar Plant 1F'],
#  [1331,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=21480),
#   'Manesar Plant 1F'],
#  [1334,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61000,
#   datetime.timedelta(seconds=33120),
#   'Manesar Plant 1F'],
#  [1334,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=53880),
#   'Manesar Plant 1F'],
#  [1338,
#   datetime.date(2022, 4, 20),
#   'P10',
#   62000,
#   datetime.timedelta(seconds=32460),
#   'Manesar Plant 1F'],
#  [1338,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=60840),
#   'Manesar Plant 1F'],
#  [1342,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81500,
#   datetime.timedelta(seconds=34500),
#   'Manesar Plant 1F'],
#  [1342,
#   datetime.date(2022, 4, 20),
#   'P20',
#   175000,
#   datetime.timedelta(days=-1, seconds=44520),
#   'Manesar Plant 1F'],
#  [1346,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61200,
#   datetime.timedelta(seconds=33000),
#   'Manesar Plant 1F'],
#  [1346,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=60480),
#   'Manesar Plant 1F'],
#  [1359,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81000,
#   datetime.timedelta(seconds=33300),
#   'EBQ HO - Manesar'],
#  [1359,
#   datetime.date(2022, 4, 20),
#   'P20',
#   172500,
#   datetime.timedelta(days=-1, seconds=78660),
#   'EBQ HO - Manesar'],
#  [1360,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151600,
#   datetime.timedelta(seconds=32160),
#   'Manesar Plant 1F'],
#  [1360,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1200,
#   datetime.timedelta(days=-1, seconds=53640),
#   'Manesar Plant 1F'],
#  [1361,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1361,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=53760),
#   'Manesar Plant 1F'],
#  [1363,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150600,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1363,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1000,
#   datetime.timedelta(days=-1, seconds=54300),
#   'Manesar Plant 1F'],
#  [1369,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151500,
#   datetime.timedelta(seconds=32280),
#   'Manesar Plant 1F'],
#  [1369,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1300,
#   datetime.timedelta(days=-1, seconds=21840),
#   'Manesar Plant 1F'],
#  [1370,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1370,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=51780),
#   'Manesar Plant 1F'],
#  [1380,
#   datetime.date(2022, 4, 20),
#   'P10',
#   54400,
#   datetime.timedelta(seconds=33180),
#   'Vithalapur Plant 4F'],
#  [1380,
#   datetime.date(2022, 4, 20),
#   'P20',
#   145700,
#   datetime.timedelta(days=-1, seconds=55260),
#   'Vithalapur Plant 4F'],
#  [1383,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [1383,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=85920),
#   'Manesar Plant 1F'],
#  [1387,
#   datetime.date(2022, 4, 20),
#   'P10',
#   151200,
#   datetime.timedelta(seconds=43200),
#   'Manesar Plant 1F'],
#  [1387,
#   datetime.date(2022, 4, 21),
#   'P20',
#   31200,
#   datetime.timedelta(days=-1, seconds=10980),
#   'Manesar Plant 1F'],
#  [1388,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61500,
#   datetime.timedelta(seconds=32940),
#   'Manesar Plant 1F'],
#  [1388,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152400,
#   datetime.timedelta(days=-1, seconds=53220),
#   'Manesar Plant 1F'],
#  [1389,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61100,
#   datetime.timedelta(seconds=33240),
#   'Manesar Plant 1F'],
#  [1389,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53040),
#   'Manesar Plant 1F'],
#  [1390,
#   datetime.date(2022, 4, 20),
#   'P10',
#   60900,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [1390,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152200,
#   datetime.timedelta(days=-1, seconds=85320),
#   'Manesar Plant 1F'],
#  [1391,
#   datetime.date(2022, 4, 20),
#   'P10',
#   150400,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [1391,
#   datetime.date(2022, 4, 21),
#   'P20',
#   1700,
#   datetime.timedelta(days=-1, seconds=21660),
#   'Manesar Plant 1F'],
#  [1393,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61800,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [1393,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152000,
#   datetime.timedelta(days=-1, seconds=53520),
#   'Manesar Plant 1F'],
#  [1396,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61200,
#   datetime.timedelta(seconds=33180),
#   'Manesar Plant 1F'],
#  [1396,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152500,
#   datetime.timedelta(days=-1, seconds=53520),
#   'Manesar Plant 1F'],
#  [1397,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61700,
#   datetime.timedelta(seconds=32640),
#   'Manesar Plant 1F'],
#  [1397,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53880),
#   'Manesar Plant 1F'],
#  [1398,
#   datetime.date(2022, 4, 20),
#   'P10',
#   61900,
#   datetime.timedelta(seconds=32520),
#   'Manesar Plant 1F'],
#  [1398,
#   datetime.date(2022, 4, 20),
#   'P20',
#   152100,
#   datetime.timedelta(days=-1, seconds=53820),
#   'Manesar Plant 1F'],
#  ...]

# %%
#Replacing ":" with "." and getting upto 2 decimal places in Time to make mathematical operations feasible on i
for i in range(len(l)):
  l[i][4] = l[i][4].__str__().replace(":",".")
  s=l[i][4]
  l[i][4]=s[0:-3]

for i in range(len(l_shift)):
  l_shift[i][0] = l_shift[i][0].__str__().replace(":",".")
  s=l_shift[i][0]
  l_shift[i][0]=float(s[0:-3])

# %%
data3= pd.DataFrame(l_shift,columns=['Difference'])
dataset3= pd.concat([dataset3,data3],axis=1)

# %%
#Removing redundant rows and storing in new data-structure
l2=[]
for i in range(len(l)):
  if 'P20' not in str(l[i][2]):
    l2.append(l[i])

# %%
for i in range(len(l2)):
  if 'd' in l2[i][4]:
    s=l2[i][4]
    s=float(s[7:len(s)])
    l2[i][4]=24+s

# %%
#Converting string type to float for Time column
for i in range(len(l2)):
  try:
   l2[i][4]=float("{:.2f}".format(float(l2[i][4])))
  except:                      
    print(l2[i][0],l2[i][4])

for i in range(len(l2)):
  try:
   l2[i][4]=float("{:.2f}".format(float(l2[i][4])))
  except:                      
    print(l2[i][0],l2[i][4])

# %%
l2
# Out:
# [[27, datetime.date(2022, 4, 20), 'P10', 82100, 9.07, 'Tapukara Plant 2F'],
#  [48, datetime.date(2022, 4, 20), 'P10', 81300, 9.12, 'Head Office - Manesar'],
#  [49, datetime.date(2022, 4, 20), 'P10', 81200, 10.08, 'EBQ HO - Manesar'],
#  [72, datetime.date(2022, 4, 20), 'P10', 82400, 9.57, 'EBQ HO - Manesar'],
#  [80, datetime.date(2022, 4, 20), 'P10', 81100, 12.09, 'Narsapura Plant 3F'],
#  [87, datetime.date(2022, 4, 20), 'P10', 82300, 9.22, 'EBQ HO - Manesar'],
#  [88, datetime.date(2022, 4, 20), 'P10', 80500, 9.32, 'Manesar Plant 1F'],
#  [108, datetime.date(2022, 4, 20), 'P10', 80700, 10.12, 'EBQ HO - Manesar'],
#  [125, datetime.date(2022, 4, 20), 'P10', 80700, 9.28, 'Vithalapur Plant 4F'],
#  [126, datetime.date(2022, 4, 20), 'P10', 81700, 9.03, 'Vithalapur Plant 4F'],
#  [167, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [168, datetime.date(2022, 4, 20), 'P10', 144600, 5.16, 'Vithalapur Plant 4F'],
#  [169, datetime.date(2022, 4, 20), 'P10', 82200, 9.07, 'Vithalapur Plant 4F'],
#  [172, datetime.date(2022, 4, 20), 'P10', 150900, 9.05, 'Manesar Plant 1F'],
#  [174, datetime.date(2022, 4, 20), 'P10', 80100, 9.31, 'Manesar Plant 1F'],
#  [180, datetime.date(2022, 4, 20), 'P10', 74700, 9.16, 'RO - Manesar'],
#  [181, datetime.date(2022, 4, 20), 'P10', 53300, 9.15, 'Narsapura Plant 3F'],
#  [183, datetime.date(2022, 4, 20), 'P10', 150600, 9.08, 'Manesar Plant 1F'],
#  [186, datetime.date(2022, 4, 20), 'P10', 150700, 9.05, 'Manesar Plant 1F'],
#  [190, datetime.date(2022, 4, 20), 'P10', 61300, 9.09, 'Manesar Plant 1F'],
#  [191, datetime.date(2022, 4, 20), 'P10', 233200, 7.19, 'Manesar Plant 1F'],
#  [196, datetime.date(2022, 4, 20), 'P10', 82300, 9.03, 'Vithalapur Plant 4F'],
#  [198, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [201, datetime.date(2022, 4, 20), 'P10', 143400, 9.14, 'Tapukara Plant 2F'],
#  [202, datetime.date(2022, 4, 20), 'P10', 150400, 9.07, 'Manesar Plant 1F'],
#  [205, datetime.date(2022, 4, 20), 'P10', 61400, 9.1, 'Manesar Plant 1F'],
#  [206, datetime.date(2022, 4, 20), 'P10', 143600, 9.11, 'Tapukara Plant 2F'],
#  [208, datetime.date(2022, 4, 20), 'P10', 82500, 9.04, 'Vithalapur Plant 4F'],
#  [209, datetime.date(2022, 4, 20), 'P10', 55700, 9.04, 'Vithalapur Plant 4F'],
#  [210, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [211, datetime.date(2022, 4, 20), 'P10', 80400, 9.27, 'Vithalapur Plant 4F'],
#  [214, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [221, datetime.date(2022, 4, 20), 'P10', 80900, 9.15, 'Manesar Plant 1F'],
#  [224,
#   datetime.date(2022, 4, 20),
#   'P10',
#   92900,
#   9.17,
#   'Head Office - Manesar'],
#  [240, datetime.date(2022, 4, 20), 'P10', 144200, 8.59, 'Vithalapur Plant 4F'],
#  [245, datetime.date(2022, 4, 20), 'P10', 142400, 9.21, 'Vithalapur Plant 4F'],
#  [247, datetime.date(2022, 4, 20), 'P10', 81000, 9.19, 'Tapukara Plant 2F'],
#  [251, datetime.date(2022, 4, 20), 'P10', 61500, 9.12, 'Manesar Plant 1F'],
#  [252, datetime.date(2022, 4, 20), 'P10', 53100, 9.27, 'Vithalapur Plant 4F'],
#  [253, datetime.date(2022, 4, 20), 'P10', 233200, 7.25, 'Manesar Plant 1F'],
#  [257, datetime.date(2022, 4, 20), 'P10', 82500, 7.17, 'Manesar Plant 1F'],
#  [262, datetime.date(2022, 4, 20), 'P10', 62600, 8.57, 'Manesar Plant 1F'],
#  [267, datetime.date(2022, 4, 20), 'P10', 75400, 10.55, 'Narsapura Plant 3F'],
#  [275, datetime.date(2022, 4, 20), 'P10', 81500, 11.26, 'EBQ HO - Manesar'],
#  [280, datetime.date(2022, 4, 20), 'P10', 61600, 9.05, 'Vithalapur Plant 4F'],
#  [281, datetime.date(2022, 4, 20), 'P10', 61800, 9.05, 'Manesar Plant 1F'],
#  [285, datetime.date(2022, 4, 20), 'P10', 81100, 9.17, 'Vithalapur Plant 4F'],
#  [287, datetime.date(2022, 4, 20), 'P10', 143000, 9.18, 'Tapukara Plant 2F'],
#  [288, datetime.date(2022, 4, 20), 'P10', 83000, 8.55, 'Vithalapur Plant 4F'],
#  [292, datetime.date(2022, 4, 20), 'P10', 81000, 9.2, 'Tapukara Plant 2F'],
#  [294, datetime.date(2022, 4, 20), 'P10', 150100, 9.13, 'Manesar Plant 1F'],
#  [296, datetime.date(2022, 4, 20), 'P10', 144600, 7.04, 'Tapukara Plant 2F'],
#  [297, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [298, datetime.date(2022, 4, 20), 'P10', 82100, 9.04, 'Vithalapur Plant 4F'],
#  [300, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [301, datetime.date(2022, 4, 20), 'P10', 234000, 7.11, 'Manesar Plant 1F'],
#  [302, datetime.date(2022, 4, 20), 'P10', 61700, 9.08, 'Manesar Plant 1F'],
#  [303, datetime.date(2022, 4, 20), 'P10', 81700, 13.14, 'Vithalapur Plant 4F'],
#  [306, datetime.date(2022, 4, 20), 'P10', 61900, 9.03, 'Manesar Plant 1F'],
#  [317, datetime.date(2022, 4, 20), 'P10', 151200, 9.0, 'Manesar Plant 1F'],
#  [318, datetime.date(2022, 4, 20), 'P10', 61900, 9.01, 'Manesar Plant 1F'],
#  [320, datetime.date(2022, 4, 20), 'P10', 151300, 8.58, 'Manesar Plant 1F'],
#  [322, datetime.date(2022, 4, 20), 'P10', 80500, 9.27, 'Narsapura Plant 3F'],
#  [334, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [336, datetime.date(2022, 4, 20), 'P10', 61400, 9.13, 'Manesar Plant 1F'],
#  [339, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [345, datetime.date(2022, 4, 20), 'P10', 82100, 9.04, 'Tapukara Plant 2F'],
#  [347, datetime.date(2022, 4, 20), 'P10', 233200, 7.21, 'Manesar Plant 1F'],
#  [352, datetime.date(2022, 4, 20), 'P10', 140900, 11.41, 'Narsapura Plant 3F'],
#  [361, datetime.date(2022, 4, 20), 'P10', 61800, 9.11, 'Manesar Plant 1F'],
#  [368, datetime.date(2022, 4, 20), 'P10', 74600, 12.17, 'Narsapura Plant 3F'],
#  [377, datetime.date(2022, 4, 20), 'P10', 55700, 9.0, 'Tapukara Plant 2F'],
#  [378, datetime.date(2022, 4, 20), 'P10', 143600, 9.1, 'Tapukara Plant 2F'],
#  [379, datetime.date(2022, 4, 20), 'P10', 151000, 9.0, 'Manesar Plant 1F'],
#  [381, datetime.date(2022, 4, 20), 'P10', 81800, 9.1, 'Tapukara Plant 2F'],
#  [382, datetime.date(2022, 4, 20), 'P10', 61900, 9.08, 'Manesar Plant 1F'],
#  [385, datetime.date(2022, 4, 20), 'P10', 61900, 9.11, 'Manesar Plant 1F'],
#  [386, datetime.date(2022, 4, 20), 'P10', 75700, 9.3, 'Narsapura Plant 3F'],
#  [388, datetime.date(2022, 4, 20), 'P10', 150900, 9.03, 'Manesar Plant 1F'],
#  [390, datetime.date(2022, 4, 20), 'P10', 122600, 5.0, 'Tapukara Plant 2F'],
#  [392, datetime.date(2022, 4, 20), 'P10', 80500, 9.22, 'Narsapura Plant 3F'],
#  [395, datetime.date(2022, 4, 20), 'P10', 61200, 9.15, 'Manesar Plant 1F'],
#  [396, datetime.date(2022, 4, 20), 'P10', 61100, 9.13, 'Manesar Plant 1F'],
#  [398, datetime.date(2022, 4, 20), 'P10', 61700, 9.03, 'Manesar Plant 1F'],
#  [399, datetime.date(2022, 4, 20), 'P10', 150100, 9.1, 'Manesar Plant 1F'],
#  [402, datetime.date(2022, 4, 20), 'P10', 62200, 9.02, 'Manesar Plant 1F'],
#  [405, datetime.date(2022, 4, 20), 'P10', 151600, 8.56, 'Manesar Plant 1F'],
#  [419, datetime.date(2022, 4, 20), 'P10', 150500, 9.05, 'Manesar Plant 1F'],
#  [423, datetime.date(2022, 4, 20), 'P10', 80600, 9.23, 'Narsapura Plant 3F'],
#  [424, datetime.date(2022, 4, 20), 'P10', 53000, 9.2, 'Narsapura Plant 3F'],
#  [426, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [428, datetime.date(2022, 4, 20), 'P10', 80100, 9.25, 'Narsapura Plant 3F'],
#  [429, datetime.date(2022, 4, 20), 'P10', 80500, 12.15, 'Narsapura Plant 3F'],
#  [434, datetime.date(2022, 4, 20), 'P10', 82800, 8.59, 'Manesar Plant 1F'],
#  [448, datetime.date(2022, 4, 20), 'P10', 61700, 9.08, 'Manesar Plant 1F'],
#  [449, datetime.date(2022, 4, 20), 'P10', 61000, 9.1, 'Manesar Plant 1F'],
#  [450, datetime.date(2022, 4, 20), 'P10', 150900, 4.24, 'Manesar Plant 1F'],
#  [452, datetime.date(2022, 4, 20), 'P10', 81600, 9.08, 'Manesar Plant 1F'],
#  [453, datetime.date(2022, 4, 20), 'P10', 81300, 7.32, 'Manesar Plant 1F'],
#  [456, datetime.date(2022, 4, 20), 'P10', 150000, 9.14, 'Manesar Plant 1F'],
#  [458, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [459, datetime.date(2022, 4, 20), 'P10', 150300, 9.07, 'Manesar Plant 1F'],
#  [460, datetime.date(2022, 4, 20), 'P10', 61900, 9.08, 'Manesar Plant 1F'],
#  [465, datetime.date(2022, 4, 20), 'P10', 53400, 9.18, 'Narsapura Plant 3F'],
#  [466, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [468, datetime.date(2022, 4, 20), 'P10', 81700, 9.1, 'Vithalapur Plant 4F'],
#  [471, datetime.date(2022, 4, 20), 'P10', 61900, 9.07, 'Manesar Plant 1F'],
#  [474, datetime.date(2022, 4, 20), 'P10', 151200, 9.03, 'Manesar Plant 1F'],
#  [477, datetime.date(2022, 4, 20), 'P10', 54400, 9.15, 'Tapukara Plant 2F'],
#  [486, datetime.date(2022, 4, 20), 'P10', 81900, 9.05, 'Manesar Plant 1F'],
#  [487, datetime.date(2022, 4, 20), 'P10', 61700, 9.06, 'Manesar Plant 1F'],
#  [488, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [489, datetime.date(2022, 4, 20), 'P10', 61700, 9.09, 'Manesar Plant 1F'],
#  [491, datetime.date(2022, 4, 20), 'P10', 150600, 9.07, 'Manesar Plant 1F'],
#  [492, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [493, datetime.date(2022, 4, 20), 'P10', 81000, 9.12, 'Manesar Plant 1F'],
#  [494, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Vithalapur Plant 4F'],
#  [499, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [501, datetime.date(2022, 4, 20), 'P10', 235900, 6.53, 'Manesar Plant 1F'],
#  [502, datetime.date(2022, 4, 20), 'P10', 81100, 9.13, 'Manesar Plant 1F'],
#  [504, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [506, datetime.date(2022, 4, 20), 'P10', 144500, 9.02, 'Tapukara Plant 2F'],
#  [508, datetime.date(2022, 4, 20), 'P10', 61900, 9.03, 'Manesar Plant 1F'],
#  [509, datetime.date(2022, 4, 20), 'P10', 62900, 8.56, 'Manesar Plant 1F'],
#  [510, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [511, datetime.date(2022, 4, 20), 'P10', 62000, 9.03, 'Manesar Plant 1F'],
#  [512, datetime.date(2022, 4, 20), 'P10', 61800, 9.05, 'Manesar Plant 1F'],
#  [518, datetime.date(2022, 4, 20), 'P10', 82200, 9.02, 'EBQ HO - Manesar'],
#  [519, datetime.date(2022, 4, 20), 'P10', 61100, 9.12, 'Manesar Plant 1F'],
#  [524, datetime.date(2022, 4, 20), 'P10', 151000, 9.04, 'Manesar Plant 1F'],
#  [525, datetime.date(2022, 4, 20), 'P10', 82000, 8.13, 'Tapukara Plant 2F'],
#  [526, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [528, datetime.date(2022, 4, 20), 'P10', 81600, 9.09, 'Manesar Plant 1F'],
#  [529, datetime.date(2022, 4, 20), 'P10', 82000, 9.05, 'Vithalapur Plant 4F'],
#  [532, datetime.date(2022, 4, 20), 'P10', 80900, 9.15, 'EBQ HO - Manesar'],
#  [533, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'Manesar Plant 1F'],
#  [538, datetime.date(2022, 4, 20), 'P10', 61100, 9.15, 'Manesar Plant 1F'],
#  [543, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [545, datetime.date(2022, 4, 20), 'P10', 54700, 9.42, 'Manesar Plant 1F'],
#  [547, datetime.date(2022, 4, 20), 'P10', 150100, 9.09, 'Manesar Plant 1F'],
#  [551, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [554, datetime.date(2022, 4, 20), 'P10', 60800, 9.18, 'Manesar Plant 1F'],
#  [555, datetime.date(2022, 4, 20), 'P10', 61400, 9.12, 'Manesar Plant 1F'],
#  [557, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [558, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [560, datetime.date(2022, 4, 20), 'P10', 62200, 9.01, 'Manesar Plant 1F'],
#  [562, datetime.date(2022, 4, 20), 'P10', 150800, 9.03, 'Manesar Plant 1F'],
#  [565, datetime.date(2022, 4, 20), 'P10', 142700, 5.4, 'Vithalapur Plant 4F'],
#  [567, datetime.date(2022, 4, 20), 'P10', 150700, 9.08, 'Manesar Plant 1F'],
#  [570, datetime.date(2022, 4, 20), 'P10', 55300, 9.05, 'Vithalapur Plant 4F'],
#  [580, datetime.date(2022, 4, 20), 'P10', 61500, 9.1, 'Manesar Plant 1F'],
#  [581, datetime.date(2022, 4, 20), 'P10', 83100, 8.52, 'Manesar Plant 1F'],
#  [585, datetime.date(2022, 4, 20), 'P10', 150000, 9.14, 'Manesar Plant 1F'],
#  [589, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [590, datetime.date(2022, 4, 20), 'P10', 150400, 9.06, 'Manesar Plant 1F'],
#  [592, datetime.date(2022, 4, 20), 'P10', 61300, 9.12, 'Manesar Plant 1F'],
#  [597, datetime.date(2022, 4, 20), 'P10', 233300, 7.22, 'Manesar Plant 1F'],
#  [599, datetime.date(2022, 4, 20), 'P10', 81100, 12.02, 'Narsapura Plant 3F'],
#  [605, datetime.date(2022, 4, 20), 'P10', 150100, 9.15, 'Manesar Plant 1F'],
#  [613, datetime.date(2022, 4, 20), 'P10', 225400, 7.31, 'Tapukara Plant 2F'],
#  [622, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [623, datetime.date(2022, 4, 20), 'P10', 61900, 9.04, 'Manesar Plant 1F'],
#  [629, datetime.date(2022, 4, 20), 'P10', 61500, 9.05, 'Manesar Plant 1F'],
#  [630, datetime.date(2022, 4, 20), 'P10', 54100, 9.18, 'Tapukara Plant 2F'],
#  [631, datetime.date(2022, 4, 20), 'P10', 150000, 9.13, 'Manesar Plant 1F'],
#  [633, datetime.date(2022, 4, 20), 'P10', 61600, 9.1, 'Manesar Plant 1F'],
#  [637, datetime.date(2022, 4, 20), 'P10', 61400, 9.13, 'Manesar Plant 1F'],
#  [639, datetime.date(2022, 4, 20), 'P10', 150100, 9.14, 'Manesar Plant 1F'],
#  [640, datetime.date(2022, 4, 20), 'P10', 61100, 11.13, 'Manesar Plant 1F'],
#  [641, datetime.date(2022, 4, 20), 'P10', 153300, 8.41, 'Manesar Plant 1F'],
#  [642, datetime.date(2022, 4, 20), 'P10', 150700, 9.08, 'Manesar Plant 1F'],
#  [643, datetime.date(2022, 4, 20), 'P10', 62700, 8.55, 'Manesar Plant 1F'],
#  [645, datetime.date(2022, 4, 20), 'P10', 233800, 7.12, 'Manesar Plant 1F'],
#  [646, datetime.date(2022, 4, 20), 'P10', 61300, 9.1, 'Manesar Plant 1F'],
#  [647, datetime.date(2022, 4, 20), 'P10', 80200, 9.27, 'Narsapura Plant 3F'],
#  [648, datetime.date(2022, 4, 20), 'P10', 151200, 8.58, 'Manesar Plant 1F'],
#  [650, datetime.date(2022, 4, 20), 'P10', 151100, 9.02, 'Manesar Plant 1F'],
#  [652, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [654, datetime.date(2022, 4, 20), 'P10', 61100, 9.14, 'Manesar Plant 1F'],
#  [655, datetime.date(2022, 4, 20), 'P10', 150000, 9.11, 'Manesar Plant 1F'],
#  [656, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [657, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [660, datetime.date(2022, 4, 20), 'P10', 151700, 8.56, 'Manesar Plant 1F'],
#  [661, datetime.date(2022, 4, 20), 'P10', 60800, 9.17, 'Manesar Plant 1F'],
#  [662, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [663, datetime.date(2022, 4, 20), 'P10', 62400, 9.02, 'Manesar Plant 1F'],
#  [665, datetime.date(2022, 4, 20), 'P10', 151300, 9.0, 'Manesar Plant 1F'],
#  [667, datetime.date(2022, 4, 20), 'P10', 150100, 9.11, 'Manesar Plant 1F'],
#  [668, datetime.date(2022, 4, 20), 'P10', 61400, 9.13, 'Manesar Plant 1F'],
#  [671, datetime.date(2022, 4, 20), 'P10', 61800, 15.36, 'Manesar Plant 1F'],
#  [672, datetime.date(2022, 4, 20), 'P10', 150500, 9.05, 'Manesar Plant 1F'],
#  [673, datetime.date(2022, 4, 20), 'P10', 233800, 7.14, 'Manesar Plant 1F'],
#  [675, datetime.date(2022, 4, 20), 'P10', 61800, 7.02, 'Manesar Plant 1F'],
#  [676, datetime.date(2022, 4, 20), 'P10', 150100, 9.1, 'Manesar Plant 1F'],
#  [677, datetime.date(2022, 4, 20), 'P10', 81100, 9.18, 'Tapukara Plant 2F'],
#  [678, datetime.date(2022, 4, 20), 'P10', 80600, 9.19, 'Manesar Plant 1F'],
#  [683, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [684, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [688, datetime.date(2022, 4, 20), 'P10', 151000, 9.05, 'Manesar Plant 1F'],
#  [691, datetime.date(2022, 4, 20), 'P10', 151700, 8.55, 'Manesar Plant 1F'],
#  [695, datetime.date(2022, 4, 20), 'P10', 82000, 9.07, 'Vithalapur Plant 4F'],
#  [696, datetime.date(2022, 4, 20), 'P10', 144200, 6.58, 'Tapukara Plant 2F'],
#  [697, datetime.date(2022, 4, 20), 'P10', 81000, 9.19, 'Tapukara Plant 2F'],
#  [700, datetime.date(2022, 4, 20), 'P10', 62500, 8.58, 'Manesar Plant 1F'],
#  [701, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [702, datetime.date(2022, 4, 20), 'P10', 60900, 9.12, 'Manesar Plant 1F'],
#  [705, datetime.date(2022, 4, 20), 'P10', 81700, 9.04, 'Vithalapur Plant 4F'],
#  [706, datetime.date(2022, 4, 20), 'P10', 83700, 2.56, 'Manesar Plant 1F'],
#  [707, datetime.date(2022, 4, 20), 'P10', 61300, 9.14, 'Manesar Plant 1F'],
#  [708, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [709, datetime.date(2022, 4, 20), 'P10', 150800, 9.03, 'Manesar Plant 1F'],
#  [713, datetime.date(2022, 4, 20), 'P10', 60900, 9.14, 'Manesar Plant 1F'],
#  [714, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [715, datetime.date(2022, 4, 20), 'P10', 151100, 9.01, 'Manesar Plant 1F'],
#  [719, datetime.date(2022, 4, 20), 'P10', 62300, 9.0, 'Manesar Plant 1F'],
#  [721, datetime.date(2022, 4, 20), 'P10', 61400, 9.12, 'Manesar Plant 1F'],
#  [723, datetime.date(2022, 4, 20), 'P10', 61800, 9.05, 'Manesar Plant 1F'],
#  [726, datetime.date(2022, 4, 20), 'P10', 82900, 9.28, 'Manesar Plant 1F'],
#  [727, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [730, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [732, datetime.date(2022, 4, 20), 'P10', 151100, 9.04, 'Manesar Plant 1F'],
#  [733, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [734, datetime.date(2022, 4, 20), 'P10', 64700, 8.38, 'Manesar Plant 1F'],
#  [735, datetime.date(2022, 4, 20), 'P10', 150900, 9.04, 'Manesar Plant 1F'],
#  [736, datetime.date(2022, 4, 20), 'P10', 150600, 9.05, 'Manesar Plant 1F'],
#  [737, datetime.date(2022, 4, 20), 'P10', 150500, 9.11, 'Manesar Plant 1F'],
#  [739, datetime.date(2022, 4, 20), 'P10', 145800, 9.18, 'Manesar Plant 1F'],
#  [741, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [743, datetime.date(2022, 4, 20), 'P10', 151700, 8.54, 'Manesar Plant 1F'],
#  [749, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [758, datetime.date(2022, 4, 20), 'P10', 144200, 9.05, 'Vithalapur Plant 4F'],
#  [761, datetime.date(2022, 4, 20), 'P10', 82500, 6.55, 'Manesar Plant 1F'],
#  [763, datetime.date(2022, 4, 20), 'P10', 53600, 9.28, 'Vithalapur Plant 4F'],
#  [766, datetime.date(2022, 4, 20), 'P10', 233700, 7.13, 'Manesar Plant 1F'],
#  [772, datetime.date(2022, 4, 20), 'P10', 232300, 7.27, 'Manesar Plant 1F'],
#  [778, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [786, datetime.date(2022, 4, 20), 'P10', 82200, 9.07, 'Vithalapur Plant 4F'],
#  [787, datetime.date(2022, 4, 20), 'P10', 60900, 9.16, 'EBQ HO - Manesar'],
#  [788, datetime.date(2022, 4, 20), 'P10', 62100, 9.0, 'Manesar Plant 1F'],
#  [790, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [794, datetime.date(2022, 4, 20), 'P10', 61300, 9.13, 'Manesar Plant 1F'],
#  [795, datetime.date(2022, 4, 20), 'P10', 62000, 9.06, 'Manesar Plant 1F'],
#  [797, datetime.date(2022, 4, 20), 'P10', 62500, 8.58, 'Manesar Plant 1F'],
#  [799, datetime.date(2022, 4, 20), 'P10', 145600, 9.2, 'Manesar Plant 1F'],
#  [803, datetime.date(2022, 4, 20), 'P10', 150800, 9.03, 'Manesar Plant 1F'],
#  [806, datetime.date(2022, 4, 20), 'P10', 61700, 7.04, 'Manesar Plant 1F'],
#  [811, datetime.date(2022, 4, 20), 'P10', 82100, 9.0, 'Vithalapur Plant 4F'],
#  [813, datetime.date(2022, 4, 20), 'P10', 82600, 8.54, 'Vithalapur Plant 4F'],
#  [816, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [820, datetime.date(2022, 4, 20), 'P10', 61200, 9.12, 'Vithalapur Plant 4F'],
#  [823, datetime.date(2022, 4, 20), 'P10', 81800, 9.1, 'EBQ HO - Manesar'],
#  [824, datetime.date(2022, 4, 20), 'P10', 61700, 9.08, 'Manesar Plant 1F'],
#  [825, datetime.date(2022, 4, 20), 'P10', 145800, 12.12, 'Manesar Plant 1F'],
#  [828, datetime.date(2022, 4, 20), 'P10', 150700, 9.03, 'Manesar Plant 1F'],
#  [832, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [833, datetime.date(2022, 4, 20), 'P10', 61600, 9.04, 'Manesar Plant 1F'],
#  [834, datetime.date(2022, 4, 20), 'P10', 144300, 9.03, 'Vithalapur Plant 4F'],
#  [836, datetime.date(2022, 4, 20), 'P10', 61500, 9.05, 'Manesar Plant 1F'],
#  [837, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [838, datetime.date(2022, 4, 20), 'P10', 61500, 9.06, 'Manesar Plant 1F'],
#  [839, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [840, datetime.date(2022, 4, 20), 'P10', 62400, 9.02, 'Manesar Plant 1F'],
#  [841, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [843, datetime.date(2022, 4, 20), 'P10', 61600, 9.1, 'Manesar Plant 1F'],
#  [844, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [845, datetime.date(2022, 4, 20), 'P10', 80700, 9.2, 'Narsapura Plant 3F'],
#  [846, datetime.date(2022, 4, 20), 'P10', 61900, 9.05, 'Manesar Plant 1F'],
#  [847, datetime.date(2022, 4, 20), 'P10', 150100, 9.13, 'Manesar Plant 1F'],
#  [848, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [849, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [851, datetime.date(2022, 4, 20), 'P10', 82900, 6.52, 'Manesar Plant 1F'],
#  [853, datetime.date(2022, 4, 20), 'P10', 95600, 7.26, 'Vithalapur Plant 4F'],
#  [858, datetime.date(2022, 4, 20), 'P10', 83100, 8.53, 'EBQ HO - Manesar'],
#  [860, datetime.date(2022, 4, 20), 'P10', 122700, 7.13, 'Narsapura Plant 3F'],
#  [862, datetime.date(2022, 4, 20), 'P10', 81500, 9.2, 'Tapukara Plant 2F'],
#  [863, datetime.date(2022, 4, 20), 'P10', 82100, 9.08, 'Vithalapur Plant 4F'],
#  [865, datetime.date(2022, 4, 20), 'P10', 81800, 9.06, 'Vithalapur Plant 4F'],
#  [874, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [875, datetime.date(2022, 4, 20), 'P10', 61900, 9.04, 'Manesar Plant 1F'],
#  [878, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [879, datetime.date(2022, 4, 20), 'P10', 53600, 9.21, 'Vithalapur Plant 4F'],
#  [883, datetime.date(2022, 4, 20), 'P10', 61600, 9.04, 'Manesar Plant 1F'],
#  [888, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [896, datetime.date(2022, 4, 20), 'P10', 60800, 9.16, 'Manesar Plant 1F'],
#  [903, datetime.date(2022, 4, 20), 'P10', 82500, 8.59, 'Tapukara Plant 2F'],
#  [906, datetime.date(2022, 4, 20), 'P10', 151000, 9.02, 'Manesar Plant 1F'],
#  [907, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Vithalapur Plant 4F'],
#  [909, datetime.date(2022, 4, 20), 'P10', 62300, 9.0, 'Vithalapur Plant 4F'],
#  [910, datetime.date(2022, 4, 20), 'P10', 232900, 7.27, 'Manesar Plant 1F'],
#  [914, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [917, datetime.date(2022, 4, 20), 'P10', 151200, 9.01, 'Manesar Plant 1F'],
#  [923, datetime.date(2022, 4, 20), 'P10', 81900, 9.14, 'EBQ HO - Manesar'],
#  [925, datetime.date(2022, 4, 20), 'P10', 61400, 9.14, 'Manesar Plant 1F'],
#  [926, datetime.date(2022, 4, 20), 'P10', 151200, 8.58, 'Manesar Plant 1F'],
#  [928, datetime.date(2022, 4, 20), 'P10', 61700, 9.07, 'Manesar Plant 1F'],
#  [930, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [931, datetime.date(2022, 4, 20), 'P10', 60900, 9.14, 'Manesar Plant 1F'],
#  [932, datetime.date(2022, 4, 20), 'P10', 83300, 9.13, 'Tapukara Plant 2F'],
#  [936, datetime.date(2022, 4, 20), 'P10', 61600, 9.13, 'Manesar Plant 1F'],
#  [937, datetime.date(2022, 4, 20), 'P10', 80400, 9.44, 'Narsapura Plant 3F'],
#  [939, datetime.date(2022, 4, 20), 'P10', 82300, 9.03, 'Vithalapur Plant 4F'],
#  [941, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [946, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [947, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [950, datetime.date(2022, 4, 20), 'P10', 61500, 9.05, 'Manesar Plant 1F'],
#  [951, datetime.date(2022, 4, 20), 'P10', 61800, 9.02, 'Manesar Plant 1F'],
#  [952, datetime.date(2022, 4, 20), 'P10', 61000, 9.11, 'Manesar Plant 1F'],
#  [953, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [954, datetime.date(2022, 4, 20), 'P10', 61800, 9.04, 'Manesar Plant 1F'],
#  [956, datetime.date(2022, 4, 20), 'P10', 61900, 9.01, 'Manesar Plant 1F'],
#  [957, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [958, datetime.date(2022, 4, 20), 'P10', 61900, 9.03, 'Manesar Plant 1F'],
#  [963, datetime.date(2022, 4, 20), 'P10', 53200, 7.2, 'Vithalapur Plant 4F'],
#  [966, datetime.date(2022, 4, 20), 'P10', 60800, 9.15, 'Manesar Plant 1F'],
#  [968, datetime.date(2022, 4, 20), 'P10', 151200, 8.59, 'Manesar Plant 1F'],
#  [973, datetime.date(2022, 4, 20), 'P10', 82700, 7.25, 'Manesar Plant 1F'],
#  [974, datetime.date(2022, 4, 20), 'P10', 150900, 9.03, 'Manesar Plant 1F'],
#  [975, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [976, datetime.date(2022, 4, 20), 'P10', 81600, 10.12, 'EBQ HO - Manesar'],
#  [979, datetime.date(2022, 4, 20), 'P10', 150700, 9.05, 'Manesar Plant 1F'],
#  [980, datetime.date(2022, 4, 20), 'P10', 61600, 9.07, 'Manesar Plant 1F'],
#  [986, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [987, datetime.date(2022, 4, 20), 'P10', 82400, 6.57, 'Manesar Plant 1F'],
#  [990, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [993, datetime.date(2022, 4, 20), 'P10', 151200, 9.01, 'Manesar Plant 1F'],
#  [994, datetime.date(2022, 4, 20), 'P10', 150900, 9.03, 'Manesar Plant 1F'],
#  [999, datetime.date(2022, 4, 20), 'P10', 54700, 9.14, 'Tapukara Plant 2F'],
#  [1002, datetime.date(2022, 4, 20), 'P10', 61700, 9.13, 'Manesar Plant 1F'],
#  [1003, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1004, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [1006, datetime.date(2022, 4, 20), 'P10', 61300, 9.24, 'Manesar Plant 1F'],
#  [1007, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [1009, datetime.date(2022, 4, 20), 'P10', 53000, 9.23, 'Narsapura Plant 3F'],
#  [1013, datetime.date(2022, 4, 20), 'P10', 80200, 4.38, 'Narsapura Plant 3F'],
#  [1014, datetime.date(2022, 4, 20), 'P10', 150900, 9.05, 'Manesar Plant 1F'],
#  [1020, datetime.date(2022, 4, 20), 'P10', 62300, 9.03, 'Narsapura Plant 3F'],
#  [1021, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [1026, datetime.date(2022, 4, 20), 'P10', 62400, 9.06, 'Manesar Plant 1F'],
#  [1033, datetime.date(2022, 4, 20), 'P10', 53900, 9.18, 'Vithalapur Plant 4F'],
#  [1035, datetime.date(2022, 4, 20), 'P10', 61400, 9.06, 'Manesar Plant 1F'],
#  [1039, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [1041, datetime.date(2022, 4, 20), 'P10', 145200, 9.21, 'Manesar Plant 1F'],
#  [1043, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [1044, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [1046, datetime.date(2022, 4, 20), 'P10', 114100, 4.13, 'Manesar Plant 1F'],
#  [1047, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [1048, datetime.date(2022, 4, 20), 'P10', 61400, 9.14, 'Manesar Plant 1F'],
#  [1049, datetime.date(2022, 4, 20), 'P10', 151000, 9.0, 'Manesar Plant 1F'],
#  [1050, datetime.date(2022, 4, 20), 'P10', 61500, 9.16, 'Manesar Plant 1F'],
#  [1053, datetime.date(2022, 4, 20), 'P10', 80500, 9.24, 'Narsapura Plant 3F'],
#  [1055, datetime.date(2022, 4, 20), 'P10', 62100, 9.02, 'Manesar Plant 1F'],
#  [1058, datetime.date(2022, 4, 20), 'P10', 81700, 9.1, 'Narsapura Plant 3F'],
#  [1062,
#   datetime.date(2022, 4, 20),
#   'P10',
#   65600,
#   10.24,
#   'Head Office - Manesar'],
#  [1085, datetime.date(2022, 4, 20), 'P10', 80900, 9.18, 'Manesar Plant 1F'],
#  [1086, datetime.date(2022, 4, 20), 'P10', 80000, 9.29, 'Narsapura Plant 3F'],
#  [1087, datetime.date(2022, 4, 20), 'P10', 60900, 7.16, 'Narsapura Plant 3F'],
#  [1091, datetime.date(2022, 4, 20), 'P10', 62100, 9.06, 'Manesar Plant 1F'],
#  [1094, datetime.date(2022, 4, 20), 'P10', 121900, 5.09, 'EBQ HO - Manesar'],
#  [1095, datetime.date(2022, 4, 20), 'P10', 54100, 9.13, 'Vithalapur Plant 4F'],
#  [1098, datetime.date(2022, 4, 20), 'P10', 135300, 5.41, 'Manesar Plant 1F'],
#  [1100, datetime.date(2022, 4, 20), 'P10', 55300, 9.1, 'Vithalapur Plant 4F'],
#  [1101, datetime.date(2022, 4, 20), 'P10', 61400, 9.1, 'Manesar Plant 1F'],
#  [1103, datetime.date(2022, 4, 20), 'P10', 61400, 9.15, 'Manesar Plant 1F'],
#  [1104, datetime.date(2022, 4, 20), 'P10', 62200, 9.0, 'Manesar Plant 1F'],
#  [1105, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [1107, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [1109, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [1110, datetime.date(2022, 4, 20), 'P10', 80400, 9.18, 'Narsapura Plant 3F'],
#  [1114, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [1117, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [1118, datetime.date(2022, 4, 20), 'P10', 150700, 9.06, 'Manesar Plant 1F'],
#  [1119, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [1120, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [1122, datetime.date(2022, 4, 20), 'P10', 151100, 9.01, 'Manesar Plant 1F'],
#  [1123, datetime.date(2022, 4, 20), 'P10', 61900, 9.06, 'Manesar Plant 1F'],
#  [1129, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [1132, datetime.date(2022, 4, 20), 'P10', 81600, 9.12, 'EBQ HO - Manesar'],
#  [1137, datetime.date(2022, 4, 20), 'P10', 81800, 9.15, 'Narsapura Plant 3F'],
#  [1138, datetime.date(2022, 4, 20), 'P10', 230500, 7.2, 'Vithalapur Plant 4F'],
#  [1139, datetime.date(2022, 4, 20), 'P10', 61000, 9.21, 'Manesar Plant 1F'],
#  [1140, datetime.date(2022, 4, 20), 'P10', 233700, 7.13, 'Manesar Plant 1F'],
#  [1142, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1143, datetime.date(2022, 4, 20), 'P10', 61900, 9.24, 'Manesar Plant 1F'],
#  [1145, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [1147, datetime.date(2022, 4, 20), 'P10', 61600, 9.04, 'Manesar Plant 1F'],
#  [1151, datetime.date(2022, 4, 20), 'P10', 150800, 9.03, 'Manesar Plant 1F'],
#  [1152, datetime.date(2022, 4, 20), 'P10', 150800, 9.02, 'Manesar Plant 1F'],
#  [1153, datetime.date(2022, 4, 20), 'P10', 62000, 9.01, 'Manesar Plant 1F'],
#  [1154, datetime.date(2022, 4, 20), 'P10', 60800, 9.13, 'Manesar Plant 1F'],
#  [1155, datetime.date(2022, 4, 20), 'P10', 151000, 9.0, 'Manesar Plant 1F'],
#  [1156, datetime.date(2022, 4, 20), 'P10', 150300, 9.07, 'Manesar Plant 1F'],
#  [1157, datetime.date(2022, 4, 20), 'P10', 61200, 9.11, 'Manesar Plant 1F'],
#  [1158, datetime.date(2022, 4, 20), 'P10', 152800, 8.43, 'Manesar Plant 1F'],
#  [1159, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [1160, datetime.date(2022, 4, 20), 'P10', 151700, 9.01, 'Manesar Plant 1F'],
#  [1162, datetime.date(2022, 4, 20), 'P10', 62200, 8.58, 'Manesar Plant 1F'],
#  [1164, datetime.date(2022, 4, 20), 'P10', 61200, 9.17, 'Manesar Plant 1F'],
#  [1166, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [1167, datetime.date(2022, 4, 20), 'P10', 111400, 5.12, 'Manesar Plant 1F'],
#  [1168, datetime.date(2022, 4, 20), 'P10', 150900, 9.03, 'Manesar Plant 1F'],
#  [1169, datetime.date(2022, 4, 20), 'P10', 60900, 9.11, 'Manesar Plant 1F'],
#  [1170, datetime.date(2022, 4, 20), 'P10', 61900, 9.08, 'Manesar Plant 1F'],
#  [1171, datetime.date(2022, 4, 20), 'P10', 53900, 9.17, 'Vithalapur Plant 4F'],
#  [1174, datetime.date(2022, 4, 20), 'P10', 151700, 8.54, 'Manesar Plant 1F'],
#  [1176, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [1180, datetime.date(2022, 4, 20), 'P10', 151000, 9.02, 'Manesar Plant 1F'],
#  [1183, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [1184,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143700,
#   9.08,
#   'Vithalapur Plant 4F'],
#  [1185, datetime.date(2022, 4, 20), 'P10', 61800, 9.03, 'Manesar Plant 1F'],
#  [1191, datetime.date(2022, 4, 20), 'P10', 151600, 8.57, 'Manesar Plant 1F'],
#  [1193, datetime.date(2022, 4, 20), 'P10', 151800, 8.52, 'Manesar Plant 1F'],
#  [1195, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [1196, datetime.date(2022, 4, 20), 'P10', 64600, 8.34, 'Manesar Plant 1F'],
#  [1200, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [1202, datetime.date(2022, 4, 20), 'P10', 61600, 9.08, 'Manesar Plant 1F'],
#  [1204, datetime.date(2022, 4, 20), 'P10', 60900, 11.15, 'Manesar Plant 1F'],
#  [1205, datetime.date(2022, 4, 20), 'P10', 61500, 9.13, 'Manesar Plant 1F'],
#  [1206, datetime.date(2022, 4, 20), 'P10', 150100, 9.09, 'Manesar Plant 1F'],
#  [1208, datetime.date(2022, 4, 20), 'P10', 61100, 9.21, 'Manesar Plant 1F'],
#  [1209, datetime.date(2022, 4, 20), 'P10', 151100, 9.01, 'Manesar Plant 1F'],
#  [1211, datetime.date(2022, 4, 20), 'P10', 232800, 7.22, 'Manesar Plant 1F'],
#  [1214, datetime.date(2022, 4, 20), 'P10', 61300, 9.07, 'Manesar Plant 1F'],
#  [1216, datetime.date(2022, 4, 20), 'P10', 233900, 7.12, 'Manesar Plant 1F'],
#  [1217, datetime.date(2022, 4, 20), 'P10', 151700, 8.55, 'Manesar Plant 1F'],
#  [1221, datetime.date(2022, 4, 20), 'P10', 82300, 12.04, 'EBQ HO - Manesar'],
#  [1224, datetime.date(2022, 4, 20), 'P10', 61300, 9.09, 'Manesar Plant 1F'],
#  [1225, datetime.date(2022, 4, 20), 'P10', 61600, 9.05, 'Manesar Plant 1F'],
#  [1226, datetime.date(2022, 4, 20), 'P10', 62000, 9.01, 'Manesar Plant 1F'],
#  [1227, datetime.date(2022, 4, 20), 'P10', 61800, 9.03, 'Manesar Plant 1F'],
#  [1228, datetime.date(2022, 4, 20), 'P10', 150200, 12.39, 'Manesar Plant 1F'],
#  [1230, datetime.date(2022, 4, 20), 'P10', 150500, 9.05, 'Manesar Plant 1F'],
#  [1231, datetime.date(2022, 4, 20), 'P10', 145900, 9.11, 'Manesar Plant 1F'],
#  [1232, datetime.date(2022, 4, 20), 'P10', 62100, 9.1, 'Manesar Plant 1F'],
#  [1233, datetime.date(2022, 4, 20), 'P10', 81100, 9.18, 'Vithalapur Plant 4F'],
#  [1234, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [1235, datetime.date(2022, 4, 20), 'P10', 64700, 8.34, 'Manesar Plant 1F'],
#  [1238, datetime.date(2022, 4, 20), 'P10', 60900, 9.16, 'Manesar Plant 1F'],
#  [1239, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [1240, datetime.date(2022, 4, 20), 'P10', 233000, 7.22, 'Manesar Plant 1F'],
#  [1246, datetime.date(2022, 4, 20), 'P10', 150700, 9.06, 'Manesar Plant 1F'],
#  [1248, datetime.date(2022, 4, 20), 'P10', 151000, 9.02, 'Manesar Plant 1F'],
#  [1249, datetime.date(2022, 4, 20), 'P10', 232300, 7.29, 'Manesar Plant 1F'],
#  [1250, datetime.date(2022, 4, 20), 'P10', 62200, 9.04, 'Manesar Plant 1F'],
#  [1259, datetime.date(2022, 4, 20), 'P10', 234000, 7.15, 'Manesar Plant 1F'],
#  [1260, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [1264, datetime.date(2022, 4, 20), 'P10', 61300, 9.09, 'Manesar Plant 1F'],
#  [1265, datetime.date(2022, 4, 20), 'P10', 232400, 7.26, 'Manesar Plant 1F'],
#  [1267, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [1269, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [1270, datetime.date(2022, 4, 20), 'P10', 62000, 9.03, 'Manesar Plant 1F'],
#  [1271, datetime.date(2022, 4, 20), 'P10', 62100, 9.04, 'Manesar Plant 1F'],
#  [1273, datetime.date(2022, 4, 20), 'P10', 150300, 9.07, 'Manesar Plant 1F'],
#  [1274, datetime.date(2022, 4, 20), 'P10', 61200, 9.25, 'Manesar Plant 1F'],
#  [1275, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [1276, datetime.date(2022, 4, 20), 'P10', 153200, 8.39, 'Manesar Plant 1F'],
#  [1277, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [1278, datetime.date(2022, 4, 20), 'P10', 61300, 9.09, 'Manesar Plant 1F'],
#  [1279, datetime.date(2022, 4, 20), 'P10', 62700, 9.0, 'Manesar Plant 1F'],
#  [1280, datetime.date(2022, 4, 20), 'P10', 151200, 8.58, 'Manesar Plant 1F'],
#  [1282, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [1285, datetime.date(2022, 4, 20), 'P10', 61400, 9.14, 'Manesar Plant 1F'],
#  [1288, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [1290, datetime.date(2022, 4, 20), 'P10', 61900, 9.04, 'Manesar Plant 1F'],
#  [1291, datetime.date(2022, 4, 20), 'P10', 150800, 9.06, 'Manesar Plant 1F'],
#  [1292, datetime.date(2022, 4, 20), 'P10', 152800, 8.45, 'Manesar Plant 1F'],
#  [1295, datetime.date(2022, 4, 20), 'P10', 82300, 9.03, 'Vithalapur Plant 4F'],
#  [1301, datetime.date(2022, 4, 20), 'P10', 61300, 9.15, 'Manesar Plant 1F'],
#  [1303, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [1305, datetime.date(2022, 4, 20), 'P10', 233800, 7.15, 'Manesar Plant 1F'],
#  [1306, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [1307, datetime.date(2022, 4, 20), 'P10', 151500, 8.56, 'Manesar Plant 1F'],
#  [1315, datetime.date(2022, 4, 20), 'P10', 53800, 9.13, 'Vithalapur Plant 4F'],
#  [1319, datetime.date(2022, 4, 20), 'P10', 150100, 9.1, 'Manesar Plant 1F'],
#  [1320, datetime.date(2022, 4, 20), 'P10', 153200, 8.4, 'Manesar Plant 1F'],
#  [1322, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [1323, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [1324, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [1326, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [1331, datetime.date(2022, 4, 20), 'P10', 150600, 9.06, 'Manesar Plant 1F'],
#  [1334, datetime.date(2022, 4, 20), 'P10', 61000, 9.12, 'Manesar Plant 1F'],
#  [1338, datetime.date(2022, 4, 20), 'P10', 62000, 9.01, 'Manesar Plant 1F'],
#  [1342, datetime.date(2022, 4, 20), 'P10', 81500, 9.35, 'Manesar Plant 1F'],
#  [1346, datetime.date(2022, 4, 20), 'P10', 61200, 9.1, 'Manesar Plant 1F'],
#  [1359, datetime.date(2022, 4, 20), 'P10', 81000, 9.15, 'EBQ HO - Manesar'],
#  [1360, datetime.date(2022, 4, 20), 'P10', 151600, 8.56, 'Manesar Plant 1F'],
#  [1361, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [1363, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [1369, datetime.date(2022, 4, 20), 'P10', 151500, 8.58, 'Manesar Plant 1F'],
#  [1370, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [1380, datetime.date(2022, 4, 20), 'P10', 54400, 9.13, 'Vithalapur Plant 4F'],
#  [1383, datetime.date(2022, 4, 20), 'P10', 61800, 9.02, 'Manesar Plant 1F'],
#  [1387, datetime.date(2022, 4, 20), 'P10', 151200, 12.0, 'Manesar Plant 1F'],
#  [1388, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [1389, datetime.date(2022, 4, 20), 'P10', 61100, 9.14, 'Manesar Plant 1F'],
#  [1390, datetime.date(2022, 4, 20), 'P10', 60900, 9.13, 'Manesar Plant 1F'],
#  [1391, datetime.date(2022, 4, 20), 'P10', 150400, 9.13, 'Manesar Plant 1F'],
#  [1393, datetime.date(2022, 4, 20), 'P10', 61800, 9.02, 'Manesar Plant 1F'],
#  [1396, datetime.date(2022, 4, 20), 'P10', 61200, 9.13, 'Manesar Plant 1F'],
#  [1397, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [1398, datetime.date(2022, 4, 20), 'P10', 61900, 9.02, 'Manesar Plant 1F'],
#  [1399, datetime.date(2022, 4, 20), 'P10', 61800, 9.03, 'Manesar Plant 1F'],
#  [1401, datetime.date(2022, 4, 20), 'P10', 63000, 8.53, 'Manesar Plant 1F'],
#  [1402, datetime.date(2022, 4, 20), 'P10', 62300, 8.57, 'Manesar Plant 1F'],
#  [1403, datetime.date(2022, 4, 20), 'P10', 233100, 7.2, 'Manesar Plant 1F'],
#  [1404, datetime.date(2022, 4, 20), 'P10', 62100, 9.03, 'Manesar Plant 1F'],
#  [1405, datetime.date(2022, 4, 20), 'P10', 61700, 9.09, 'Manesar Plant 1F'],
#  [1406, datetime.date(2022, 4, 20), 'P10', 62700, 9.2, 'Manesar Plant 1F'],
#  [1410, datetime.date(2022, 4, 20), 'P10', 81600, 10.47, 'Manesar Plant 1F'],
#  [1416, datetime.date(2022, 4, 20), 'P10', 81000, 9.2, 'EBQ HO - Manesar'],
#  [1417, datetime.date(2022, 4, 20), 'P10', 62700, 9.04, 'Manesar Plant 1F'],
#  [1418, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [1420, datetime.date(2022, 4, 20), 'P10', 150000, 9.11, 'Manesar Plant 1F'],
#  [1422,
#   datetime.date(2022, 4, 20),
#   'P10',
#   143200,
#   9.16,
#   'Vithalapur Plant 4F'],
#  [1424, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [1425, datetime.date(2022, 4, 20), 'P10', 62100, 9.03, 'Manesar Plant 1F'],
#  [1426, datetime.date(2022, 4, 20), 'P10', 60800, 4.37, 'Manesar Plant 1F'],
#  [1427, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [1432, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1434, datetime.date(2022, 4, 20), 'P10', 150000, 9.1, 'Manesar Plant 1F'],
#  [1436, datetime.date(2022, 4, 20), 'P10', 54000, 9.14, 'Vithalapur Plant 4F'],
#  [1438, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [1442, datetime.date(2022, 4, 20), 'P10', 62000, 9.02, 'Manesar Plant 1F'],
#  [1451, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [1452, datetime.date(2022, 4, 20), 'P10', 61900, 7.02, 'Manesar Plant 1F'],
#  [1453, datetime.date(2022, 4, 20), 'P10', 150500, 9.07, 'Manesar Plant 1F'],
#  [1455, datetime.date(2022, 4, 20), 'P10', 62100, 7.0, 'Manesar Plant 1F'],
#  [1456, datetime.date(2022, 4, 20), 'P10', 232400, 7.3, 'Manesar Plant 1F'],
#  [1461, datetime.date(2022, 4, 20), 'P10', 81900, 9.32, 'RO - Manesar'],
#  [1464, datetime.date(2022, 4, 20), 'P10', 61600, 9.09, 'Manesar Plant 1F'],
#  [1465, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [1467, datetime.date(2022, 4, 20), 'P10', 233700, 7.16, 'Manesar Plant 1F'],
#  [1470, datetime.date(2022, 4, 20), 'P10', 61900, 9.06, 'Manesar Plant 1F'],
#  [1472, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [1473, datetime.date(2022, 4, 20), 'P10', 150400, 9.06, 'Manesar Plant 1F'],
#  [1477, datetime.date(2022, 4, 20), 'P10', 60900, 9.14, 'Manesar Plant 1F'],
#  [1478, datetime.date(2022, 4, 20), 'P10', 54600, 9.1, 'Vithalapur Plant 4F'],
#  [1479, datetime.date(2022, 4, 20), 'P10', 62500, 8.56, 'Manesar Plant 1F'],
#  [1481, datetime.date(2022, 4, 20), 'P10', 61100, 9.1, 'Manesar Plant 1F'],
#  [1483, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [1484, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [1485, datetime.date(2022, 4, 20), 'P10', 150300, 9.07, 'Manesar Plant 1F'],
#  [1489, datetime.date(2022, 4, 20), 'P10', 62700, 8.56, 'Manesar Plant 1F'],
#  [1490, datetime.date(2022, 4, 20), 'P10', 61800, 9.04, 'Manesar Plant 1F'],
#  [1493, datetime.date(2022, 4, 20), 'P10', 150400, 9.11, 'Manesar Plant 1F'],
#  [1497, datetime.date(2022, 4, 20), 'P10', 145700, 9.13, 'Manesar Plant 1F'],
#  [1498, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [1499, datetime.date(2022, 4, 20), 'P10', 151700, 8.55, 'Manesar Plant 1F'],
#  [1501, datetime.date(2022, 4, 20), 'P10', 150300, 9.1, 'Manesar Plant 1F'],
#  [1502, datetime.date(2022, 4, 20), 'P10', 61300, 9.12, 'Manesar Plant 1F'],
#  [1503, datetime.date(2022, 4, 20), 'P10', 150800, 9.03, 'Manesar Plant 1F'],
#  [1504, datetime.date(2022, 4, 20), 'P10', 61300, 9.13, 'Manesar Plant 1F'],
#  [1505, datetime.date(2022, 4, 20), 'P10', 150000, 9.11, 'Manesar Plant 1F'],
#  [1508, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [1509, datetime.date(2022, 4, 20), 'P10', 60800, 9.18, 'Manesar Plant 1F'],
#  [1510, datetime.date(2022, 4, 20), 'P10', 81300, 9.15, 'Vithalapur Plant 4F'],
#  [1512, datetime.date(2022, 4, 20), 'P10', 61900, 9.09, 'Manesar Plant 1F'],
#  [1513, datetime.date(2022, 4, 20), 'P10', 80400, 9.18, 'Narsapura Plant 3F'],
#  [1515, datetime.date(2022, 4, 20), 'P10', 150300, 9.1, 'Manesar Plant 1F'],
#  [1519, datetime.date(2022, 4, 20), 'P10', 61100, 9.12, 'Manesar Plant 1F'],
#  [1523, datetime.date(2022, 4, 20), 'P10', 150100, 9.09, 'Manesar Plant 1F'],
#  [1525, datetime.date(2022, 4, 20), 'P10', 62200, 8.59, 'Manesar Plant 1F'],
#  [1527, datetime.date(2022, 4, 20), 'P10', 151300, 9.01, 'Manesar Plant 1F'],
#  [1532, datetime.date(2022, 4, 20), 'P10', 61600, 9.13, 'Manesar Plant 1F'],
#  [1533, datetime.date(2022, 4, 20), 'P10', 150800, 9.06, 'Manesar Plant 1F'],
#  [1537, datetime.date(2022, 4, 20), 'P10', 151700, 8.53, 'Manesar Plant 1F'],
#  [1538, datetime.date(2022, 4, 20), 'P10', 61800, 9.09, 'Manesar Plant 1F'],
#  [1541, datetime.date(2022, 4, 20), 'P10', 60900, 9.11, 'Manesar Plant 1F'],
#  [1544, datetime.date(2022, 4, 20), 'P10', 61300, 9.07, 'Manesar Plant 1F'],
#  [1546, datetime.date(2022, 4, 20), 'P10', 62600, 8.54, 'Manesar Plant 1F'],
#  [1549, datetime.date(2022, 4, 20), 'P10', 53900, 9.13, 'Vithalapur Plant 4F'],
#  [1557, datetime.date(2022, 4, 20), 'P10', 61500, 9.07, 'Manesar Plant 1F'],
#  [1558, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [1559, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [1563, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [1564, datetime.date(2022, 4, 20), 'P10', 150900, 9.06, 'Manesar Plant 1F'],
#  [1567, datetime.date(2022, 4, 20), 'P10', 150700, 9.03, 'Manesar Plant 1F'],
#  [1572, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [1574, datetime.date(2022, 4, 20), 'P10', 150500, 9.06, 'Manesar Plant 1F'],
#  [1576, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [1577, datetime.date(2022, 4, 20), 'P10', 233800, 7.14, 'Manesar Plant 1F'],
#  [1579, datetime.date(2022, 4, 20), 'P10', 80300, 9.28, 'Narsapura Plant 3F'],
#  [1580, datetime.date(2022, 4, 20), 'P10', 150900, 9.02, 'Manesar Plant 1F'],
#  [1582, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [1584, datetime.date(2022, 4, 20), 'P10', 150600, 9.08, 'Manesar Plant 1F'],
#  [1585, datetime.date(2022, 4, 20), 'P10', 60900, 9.14, 'Manesar Plant 1F'],
#  [1586, datetime.date(2022, 4, 20), 'P10', 60900, 9.11, 'Manesar Plant 1F'],
#  [1588, datetime.date(2022, 4, 20), 'P10', 62000, 9.01, 'Manesar Plant 1F'],
#  [1592, datetime.date(2022, 4, 20), 'P10', 233200, 7.24, 'Manesar Plant 1F'],
#  [1593, datetime.date(2022, 4, 20), 'P10', 62200, 9.0, 'Manesar Plant 1F'],
#  [1594, datetime.date(2022, 4, 20), 'P10', 151000, 9.0, 'Manesar Plant 1F'],
#  [1595, datetime.date(2022, 4, 20), 'P10', 61100, 9.13, 'Manesar Plant 1F'],
#  [1598, datetime.date(2022, 4, 20), 'P10', 151300, 8.58, 'Manesar Plant 1F'],
#  [1601, datetime.date(2022, 4, 20), 'P10', 150800, 9.06, 'Narsapura Plant 3F'],
#  [1621, datetime.date(2022, 4, 20), 'P10', 150100, 9.09, 'Manesar Plant 1F'],
#  [1623, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1625, datetime.date(2022, 4, 20), 'P10', 150800, 9.02, 'Manesar Plant 1F'],
#  [1626, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1628, datetime.date(2022, 4, 20), 'P10', 225700, 7.23, 'Narsapura Plant 3F'],
#  [1633, datetime.date(2022, 4, 20), 'P10', 53200, 9.16, 'Narsapura Plant 3F'],
#  [1634, datetime.date(2022, 4, 20), 'P10', 61600, 9.1, 'EBQ HO - Manesar'],
#  [1638, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [1642, datetime.date(2022, 4, 20), 'P10', 151200, 8.59, 'Manesar Plant 1F'],
#  [1643, datetime.date(2022, 4, 20), 'P10', 60900, 9.13, 'Manesar Plant 1F'],
#  [1645, datetime.date(2022, 4, 20), 'P10', 61400, 9.11, 'Manesar Plant 1F'],
#  [1654, datetime.date(2022, 4, 20), 'P10', 61700, 9.06, 'Manesar Plant 1F'],
#  [1656, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [1663, datetime.date(2022, 4, 20), 'P10', 81700, 9.45, 'Narsapura Plant 3F'],
#  [1667, datetime.date(2022, 4, 20), 'P10', 81500, 9.05, 'Vithalapur Plant 4F'],
#  [1670, datetime.date(2022, 4, 20), 'P10', 62300, 8.58, 'Manesar Plant 1F'],
#  [1672, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'Manesar Plant 1F'],
#  [1673, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [1675, datetime.date(2022, 4, 20), 'P10', 62500, 8.57, 'Manesar Plant 1F'],
#  [1677, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [1682, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [1684, datetime.date(2022, 4, 20), 'P10', 62300, 9.01, 'Manesar Plant 1F'],
#  [1686, datetime.date(2022, 4, 20), 'P10', 80500, 9.17, 'Narsapura Plant 3F'],
#  [1688, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [1690, datetime.date(2022, 4, 20), 'P10', 233800, 7.13, 'Manesar Plant 1F'],
#  [1691, datetime.date(2022, 4, 20), 'P10', 152800, 8.43, 'Manesar Plant 1F'],
#  [1692, datetime.date(2022, 4, 20), 'P10', 60800, 9.13, 'Manesar Plant 1F'],
#  [1693, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
# ...
#  [2090, datetime.date(2022, 4, 20), 'P10', 232400, 7.26, 'Manesar Plant 1F'],
#  [2094, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [2098, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Narsapura Plant 3F'],
#  [2100, datetime.date(2022, 4, 20), 'P10', 61700, 9.05, 'Manesar Plant 1F'],
#  [2102, datetime.date(2022, 4, 20), 'P10', 151100, 9.0, 'Manesar Plant 1F'],
#  [2103, datetime.date(2022, 4, 20), 'P10', 153200, 8.39, 'Manesar Plant 1F'],
#  [2104, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [2106, datetime.date(2022, 4, 20), 'P10', 150900, 9.02, 'Manesar Plant 1F'],
#  [2108, datetime.date(2022, 4, 20), 'P10', 62500, 4.27, 'Manesar Plant 1F'],
#  [2109, datetime.date(2022, 4, 20), 'P10', 82400, 7.01, 'Manesar Plant 1F'],
#  [2110, datetime.date(2022, 4, 20), 'P10', 62200, 9.02, 'Manesar Plant 1F'],
#  [2117, datetime.date(2022, 4, 20), 'P10', 62100, 9.07, 'Manesar Plant 1F'],
#  [2119, datetime.date(2022, 4, 20), 'P10', 62100, 9.03, 'Manesar Plant 1F'],
#  [2120, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [2127, datetime.date(2022, 4, 20), 'P10', 151100, 4.22, 'Manesar Plant 1F'],
#  [2129, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [2130, datetime.date(2022, 4, 20), 'P10', 151300, 8.57, 'Manesar Plant 1F'],
#  [2131, datetime.date(2022, 4, 20), 'P10', 62700, 9.04, 'Manesar Plant 1F'],
#  [2132, datetime.date(2022, 4, 20), 'P10', 150900, 9.01, 'Manesar Plant 1F'],
#  [2133, datetime.date(2022, 4, 20), 'P10', 62100, 9.01, 'Manesar Plant 1F'],
#  [2134, datetime.date(2022, 4, 20), 'P10', 151200, 9.0, 'Manesar Plant 1F'],
#  [2135, datetime.date(2022, 4, 20), 'P10', 82400, 9.03, 'Manesar Plant 1F'],
#  [2136, datetime.date(2022, 4, 20), 'P10', 151400, 8.57, 'Manesar Plant 1F'],
#  [2137, datetime.date(2022, 4, 20), 'P10', 61600, 9.04, 'Manesar Plant 1F'],
#  [2138, datetime.date(2022, 4, 20), 'P10', 61600, 9.1, 'Manesar Plant 1F'],
#  [2143, datetime.date(2022, 4, 20), 'P10', 62000, 9.03, 'Manesar Plant 1F'],
#  [2144, datetime.date(2022, 4, 20), 'P10', 234000, 7.12, 'Manesar Plant 1F'],
#  [2145, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [2147, datetime.date(2022, 4, 20), 'P10', 61800, 9.05, 'Manesar Plant 1F'],
#  [2148, datetime.date(2022, 4, 20), 'P10', 152800, 8.42, 'Manesar Plant 1F'],
#  [2150, datetime.date(2022, 4, 20), 'P10', 61300, 9.12, 'Manesar Plant 1F'],
#  [2152, datetime.date(2022, 4, 20), 'P10', 234000, 7.12, 'Manesar Plant 1F'],
#  [2155, datetime.date(2022, 4, 20), 'P10', 233800, 7.16, 'Manesar Plant 1F'],
#  [2157, datetime.date(2022, 4, 20), 'P10', 61600, 9.09, 'Manesar Plant 1F'],
#  [2160, datetime.date(2022, 4, 20), 'P10', 234300, 7.15, 'Manesar Plant 1F'],
#  [2162, datetime.date(2022, 4, 20), 'P10', 235900, 6.53, 'Manesar Plant 1F'],
#  [2163, datetime.date(2022, 4, 20), 'P10', 55300, 9.01, 'Vithalapur Plant 4F'],
#  [2164, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [2165, datetime.date(2022, 4, 20), 'P10', 60800, 9.14, 'Manesar Plant 1F'],
#  [2166, datetime.date(2022, 4, 20), 'P10', 150500, 9.05, 'Manesar Plant 1F'],
#  [2167, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [2168, datetime.date(2022, 4, 20), 'P10', 150800, 9.02, 'Manesar Plant 1F'],
#  [2169, datetime.date(2022, 4, 20), 'P10', 150700, 9.04, 'Manesar Plant 1F'],
#  [2170, datetime.date(2022, 4, 20), 'P10', 61100, 9.11, 'Manesar Plant 1F'],
#  [2171, datetime.date(2022, 4, 20), 'P10', 61900, 9.04, 'Manesar Plant 1F'],
#  [2174, datetime.date(2022, 4, 20), 'P10', 61300, 9.1, 'Manesar Plant 1F'],
#  [2175, datetime.date(2022, 4, 20), 'P10', 151600, 8.55, 'Manesar Plant 1F'],
#  [2184, datetime.date(2022, 4, 20), 'P10', 82200, 10.23, 'Manesar Plant 1F'],
#  [2192, datetime.date(2022, 4, 20), 'P10', 84800, 9.23, 'EBQ HO - Manesar'],
#  [2198, datetime.date(2022, 4, 20), 'P10', 61800, 9.02, 'Manesar Plant 1F'],
#  [2208, datetime.date(2022, 4, 20), 'P10', 151000, 9.02, 'Manesar Plant 1F'],
#  [2209, datetime.date(2022, 4, 20), 'P10', 150900, 9.03, 'Manesar Plant 1F'],
#  [2210, datetime.date(2022, 4, 20), 'P10', 151000, 9.04, 'Manesar Plant 1F'],
#  [2211, datetime.date(2022, 4, 20), 'P10', 151300, 8.58, 'Manesar Plant 1F'],
#  [2213, datetime.date(2022, 4, 20), 'P10', 61900, 9.13, 'Manesar Plant 1F'],
#  [2214, datetime.date(2022, 4, 20), 'P10', 61600, 9.07, 'Manesar Plant 1F'],
#  [2215, datetime.date(2022, 4, 20), 'P10', 55300, 9.05, 'Vithalapur Plant 4F'],
#  [2217, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [2218, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'Manesar Plant 1F'],
#  [2219, datetime.date(2022, 4, 20), 'P10', 61300, 9.1, 'Manesar Plant 1F'],
#  [2220, datetime.date(2022, 4, 20), 'P10', 82300, 7.03, 'Manesar Plant 1F'],
#  [2221, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'Manesar Plant 1F'],
#  [2222, datetime.date(2022, 4, 20), 'P10', 61500, 9.1, 'Manesar Plant 1F'],
#  [2224, datetime.date(2022, 4, 20), 'P10', 61700, 9.06, 'Manesar Plant 1F'],
#  [2225, datetime.date(2022, 4, 20), 'P10', 81000, 9.16, 'Tapukara Plant 2F'],
#  [2226, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [2227, datetime.date(2022, 4, 20), 'P10', 150900, 9.02, 'Manesar Plant 1F'],
#  [2228, datetime.date(2022, 4, 20), 'P10', 151200, 8.59, 'Manesar Plant 1F'],
#  [2230, datetime.date(2022, 4, 20), 'P10', 61400, 9.12, 'Manesar Plant 1F'],
#  [2238, datetime.date(2022, 4, 20), 'P10', 151000, 4.23, 'Narsapura Plant 3F'],
#  [2239, datetime.date(2022, 4, 20), 'P10', 151700, 12.24, 'Manesar Plant 1F'],
#  [2240, datetime.date(2022, 4, 20), 'P10', 150400, 9.09, 'Manesar Plant 1F'],
#  [2245, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [2246, datetime.date(2022, 4, 20), 'P10', 61700, 9.04, 'Manesar Plant 1F'],
#  [2250, datetime.date(2022, 4, 20), 'P10', 60900, 9.16, 'Manesar Plant 1F'],
#  [2251, datetime.date(2022, 4, 20), 'P10', 151100, 8.59, 'Manesar Plant 1F'],
#  [2254, datetime.date(2022, 4, 20), 'P10', 60800, 9.16, 'Manesar Plant 1F'],
#  [2255, datetime.date(2022, 4, 20), 'P10', 60900, 9.15, 'Manesar Plant 1F'],
#  [2257, datetime.date(2022, 4, 20), 'P10', 233300, 7.17, 'Manesar Plant 1F'],
#  [2258, datetime.date(2022, 4, 20), 'P10', 60900, 9.13, 'Manesar Plant 1F'],
#  [2259, datetime.date(2022, 4, 20), 'P10', 145600, 9.16, 'Manesar Plant 1F'],
#  [2261, datetime.date(2022, 4, 20), 'P10', 74800, 9.39, 'Tapukara Plant 2F'],
#  [2273, datetime.date(2022, 4, 20), 'P10', 60900, 9.16, 'Manesar Plant 1F'],
#  [2278, datetime.date(2022, 4, 20), 'P10', 82500, 9.0, 'Tapukara Plant 2F'],
#  [2282, datetime.date(2022, 4, 20), 'P10', 151500, 12.35, 'Manesar Plant 1F'],
#  [2284, datetime.date(2022, 4, 20), 'P10', 61300, 9.1, 'Manesar Plant 1F'],
#  [2286, datetime.date(2022, 4, 20), 'P10', 61500, 9.13, 'Manesar Plant 1F'],
#  [2288, datetime.date(2022, 4, 20), 'P10', 150800, 9.05, 'Manesar Plant 1F'],
#  [2289, datetime.date(2022, 4, 20), 'P10', 150100, 9.13, 'Manesar Plant 1F'],
#  [2290, datetime.date(2022, 4, 20), 'P10', 151600, 8.57, 'Manesar Plant 1F'],
#  [2291, datetime.date(2022, 4, 20), 'P10', 163200, 7.4, 'Manesar Plant 1F'],
#  [2292, datetime.date(2022, 4, 20), 'P10', 61400, 9.06, 'Manesar Plant 1F'],
#  [2293, datetime.date(2022, 4, 20), 'P10', 102800, 2.21, 'Manesar Plant 1F'],
#  [2294, datetime.date(2022, 4, 20), 'P10', 123500, 3.51, 'Manesar Plant 1F'],
#  [2295, datetime.date(2022, 4, 20), 'P10', 61100, 9.12, 'Manesar Plant 1F'],
#  [2296, datetime.date(2022, 4, 20), 'P10', 153300, 8.38, 'Manesar Plant 1F'],
#  [2297, datetime.date(2022, 4, 20), 'P10', 151700, 8.53, 'Manesar Plant 1F'],
#  [2298, datetime.date(2022, 4, 20), 'P10', 151500, 8.56, 'Manesar Plant 1F'],
#  [2299, datetime.date(2022, 4, 20), 'P10', 61900, 9.05, 'Manesar Plant 1F'],
#  [2301, datetime.date(2022, 4, 20), 'P10', 60900, 9.11, 'Manesar Plant 1F'],
#  [2302, datetime.date(2022, 4, 20), 'P10', 151100, 8.59, 'Manesar Plant 1F'],
#  [2304, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [2305, datetime.date(2022, 4, 20), 'P10', 61300, 9.11, 'Manesar Plant 1F'],
#  [2306, datetime.date(2022, 4, 20), 'P10', 61900, 9.04, 'Manesar Plant 1F'],
#  [2308, datetime.date(2022, 4, 20), 'P10', 151600, 8.54, 'Manesar Plant 1F'],
#  [2310, datetime.date(2022, 4, 20), 'P10', 62100, 8.59, 'Manesar Plant 1F'],
#  [2311, datetime.date(2022, 4, 20), 'P10', 62000, 9.04, 'Manesar Plant 1F'],
#  [2312, datetime.date(2022, 4, 20), 'P10', 62300, 9.01, 'Manesar Plant 1F'],
#  [2314, datetime.date(2022, 4, 20), 'P10', 151200, 12.0, 'Manesar Plant 1F'],
#  [2315, datetime.date(2022, 4, 20), 'P10', 61400, 9.1, 'EBQ HO - Manesar'],
#  [2317, datetime.date(2022, 4, 20), 'P10', 153300, 8.37, 'Manesar Plant 1F'],
#  [2318, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [2319, datetime.date(2022, 4, 20), 'P10', 61300, 9.09, 'Manesar Plant 1F'],
#  [2321, datetime.date(2022, 4, 20), 'P10', 145600, 9.15, 'Manesar Plant 1F'],
#  [2325, datetime.date(2022, 4, 20), 'P10', 61200, 9.17, 'Manesar Plant 1F'],
#  [2326, datetime.date(2022, 4, 20), 'P10', 234500, 7.07, 'Manesar Plant 1F'],
#  [2327, datetime.date(2022, 4, 20), 'P10', 53900, 9.21, 'Tapukara Plant 2F'],
#  [2329, datetime.date(2022, 4, 20), 'P10', 61700, 9.13, 'Narsapura Plant 3F'],
#  [2332, datetime.date(2022, 4, 20), 'P10', 61300, 7.11, 'Manesar Plant 1F'],
#  [2336, datetime.date(2022, 4, 20), 'P10', 62100, 9.03, 'Narsapura Plant 3F'],
#  [2337, datetime.date(2022, 4, 20), 'P10', 61500, 9.13, 'Manesar Plant 1F'],
#  [2338, datetime.date(2022, 4, 20), 'P10', 232400, 7.3, 'Manesar Plant 1F'],
#  [2340, datetime.date(2022, 4, 20), 'P10', 61600, 9.05, 'Manesar Plant 1F'],
#  [2341, datetime.date(2022, 4, 20), 'P10', 150700, 9.08, 'Manesar Plant 1F'],
#  [2342, datetime.date(2022, 4, 20), 'P10', 82300, 9.03, 'Vithalapur Plant 4F'],
#  [2346, datetime.date(2022, 4, 20), 'P10', 60900, 9.12, 'Manesar Plant 1F'],
#  [2349, datetime.date(2022, 4, 20), 'P10', 61400, 9.14, 'Manesar Plant 1F'],
#  [2356, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'EBQ HO - Manesar'],
#  [2361, datetime.date(2022, 4, 20), 'P10', 150800, 4.22, 'Manesar Plant 1F'],
#  [2362, datetime.date(2022, 4, 20), 'P10', 61900, 9.06, 'Manesar Plant 1F'],
#  [2364, datetime.date(2022, 4, 20), 'P10', 61100, 9.12, 'Manesar Plant 1F'],
#  [2365, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [2366, datetime.date(2022, 4, 20), 'P10', 62100, 9.0, 'Manesar Plant 1F'],
#  [2367, datetime.date(2022, 4, 20), 'P10', 61000, 9.13, 'Manesar Plant 1F'],
#  [2369, datetime.date(2022, 4, 20), 'P10', 60800, 9.13, 'Manesar Plant 1F'],
#  [2370, datetime.date(2022, 4, 20), 'P10', 61500, 9.06, 'Manesar Plant 1F'],
#  [2371, datetime.date(2022, 4, 20), 'P10', 61800, 9.07, 'Manesar Plant 1F'],
#  [2372, datetime.date(2022, 4, 20), 'P10', 61400, 9.14, 'Manesar Plant 1F'],
#  [2374, datetime.date(2022, 4, 20), 'P10', 151400, 8.57, 'Manesar Plant 1F'],
#  [2385, datetime.date(2022, 4, 20), 'P10', 82100, 9.01, 'Vithalapur Plant 4F'],
#  [2386, datetime.date(2022, 4, 20), 'P10', 150700, 9.05, 'Manesar Plant 1F'],
#  [2388, datetime.date(2022, 4, 20), 'P10', 61800, 9.1, 'Manesar Plant 1F'],
#  [2394,
#   datetime.date(2022, 4, 20),
#   'P10',
#   81900,
#   8.54,
#   'Head Office - Manesar'],
#  [2397, datetime.date(2022, 4, 20), 'P10', 61900, 9.01, 'Manesar Plant 1F'],
#  [2402, datetime.date(2022, 4, 20), 'P10', 234500, 7.06, 'Manesar Plant 1F'],
#  [2404, datetime.date(2022, 4, 20), 'P10', 81700, 9.35, 'Tapukara Plant 2F'],
#  [2407, datetime.date(2022, 4, 20), 'P10', 83500, 9.26, 'Vithalapur Plant 4F'],
#  [2408, datetime.date(2022, 4, 20), 'P10', 61800, 9.07, 'Manesar Plant 1F'],
#  [2410, datetime.date(2022, 4, 20), 'P10', 151200, 8.58, 'Manesar Plant 1F'],
#  [2411, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [2412, datetime.date(2022, 4, 20), 'P10', 61400, 9.08, 'Manesar Plant 1F'],
#  [2413, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [2415, datetime.date(2022, 4, 20), 'P10', 150600, 9.04, 'Manesar Plant 1F'],
#  [2416, datetime.date(2022, 4, 20), 'P10', 151400, 8.57, 'Manesar Plant 1F'],
#  [2417, datetime.date(2022, 4, 20), 'P10', 151400, 8.56, 'Manesar Plant 1F'],
#  [2418, datetime.date(2022, 4, 20), 'P10', 61700, 13.03, 'Manesar Plant 1F'],
#  [2419, datetime.date(2022, 4, 20), 'P10', 55300, 9.03, 'Vithalapur Plant 4F'],
#  [2420, datetime.date(2022, 4, 20), 'P10', 151000, 9.04, 'Manesar Plant 1F'],
#  [2422, datetime.date(2022, 4, 20), 'P10', 151000, 9.0, 'Manesar Plant 1F'],
#  [2427, datetime.date(2022, 4, 20), 'P10', 61600, 9.11, 'Manesar Plant 1F'],
#  [2429, datetime.date(2022, 4, 20), 'P10', 61500, 9.09, 'Manesar Plant 1F'],
#  [2431, datetime.date(2022, 4, 20), 'P10', 53100, 9.17, 'Narsapura Plant 3F'],
#  [2432, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [2433, datetime.date(2022, 4, 20), 'P10', 151000, 12.35, 'Manesar Plant 1F'],
#  [2435, datetime.date(2022, 4, 20), 'P10', 61800, 9.05, 'Manesar Plant 1F'],
#  [2436, datetime.date(2022, 4, 20), 'P10', 61600, 9.06, 'Manesar Plant 1F'],
#  [2437, datetime.date(2022, 4, 20), 'P10', 61700, 9.11, 'Manesar Plant 1F'],
#  [2438, datetime.date(2022, 4, 20), 'P10', 150400, 9.07, 'Manesar Plant 1F'],
#  [2441, datetime.date(2022, 4, 20), 'P10', 151500, 8.56, 'Manesar Plant 1F'],
#  [2442, datetime.date(2022, 4, 20), 'P10', 151000, 9.02, 'Manesar Plant 1F'],
#  [2445, datetime.date(2022, 4, 20), 'P10', 54000, 9.23, 'Vithalapur Plant 4F'],
#  [2447,
#   datetime.date(2022, 4, 20),
#   'P10',
#   142700,
#   9.23,
#   'Vithalapur Plant 4F'],
#  [2454, datetime.date(2022, 4, 20), 'P10', 61500, 9.08, 'Manesar Plant 1F'],
#  [2455, datetime.date(2022, 4, 20), 'P10', 61300, 9.08, 'Manesar Plant 1F'],
#  [2458, datetime.date(2022, 4, 20), 'P10', 151500, 8.55, 'Manesar Plant 1F'],
#  [2464, datetime.date(2022, 4, 20), 'P10', 150300, 9.13, 'Manesar Plant 1F'],
#  [2470, datetime.date(2022, 4, 20), 'P10', 151000, 9.01, 'Manesar Plant 1F'],
#  [2471, datetime.date(2022, 4, 20), 'P10', 150700, 9.05, 'Manesar Plant 1F'],
#  [2472, datetime.date(2022, 4, 20), 'P10', 151400, 8.58, 'Manesar Plant 1F'],
#  [2474, datetime.date(2022, 4, 20), 'P10', 150400, 9.07, 'Manesar Plant 1F'],
#  [2476, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [2480, datetime.date(2022, 4, 20), 'P10', 60800, 9.12, 'Manesar Plant 1F'],
#  [2481, datetime.date(2022, 4, 20), 'P10', 234300, 7.09, 'Manesar Plant 1F'],
#  [2482, datetime.date(2022, 4, 20), 'P10', 150100, 9.09, 'Manesar Plant 1F'],
#  [2485, datetime.date(2022, 4, 20), 'P10', 81500, 11.25, 'EBQ HO - Manesar'],
#  [2493, datetime.date(2022, 4, 20), 'P10', 80700, 9.21, 'Tapukara Plant 2F'],
#  [2498, datetime.date(2022, 4, 20), 'P10', 145600, 9.16, 'Manesar Plant 1F'],
#  [2499, datetime.date(2022, 4, 20), 'P10', 150000, 9.12, 'Manesar Plant 1F'],
#  [2500, datetime.date(2022, 4, 20), 'P10', 61900, 7.06, 'Narsapura Plant 3F'],
#  [2501, datetime.date(2022, 4, 20), 'P10', 150800, 9.04, 'Manesar Plant 1F'],
#  [2503, datetime.date(2022, 4, 20), 'P10', 151000, 9.03, 'Manesar Plant 1F'],
#  [2504, datetime.date(2022, 4, 20), 'P10', 61400, 9.09, 'Manesar Plant 1F'],
#  [2507, datetime.date(2022, 4, 20), 'P10', 61400, 9.07, 'Manesar Plant 1F'],
#  [2508, datetime.date(2022, 4, 20), 'P10', 80500, 7.18, 'Manesar Plant 1F'],
#  [2514, datetime.date(2022, 4, 20), 'P10', 151500, 8.55, 'Manesar Plant 1F'],
#  [2518, datetime.date(2022, 4, 20), 'P10', 61000, 9.12, 'Manesar Plant 1F'],
#  [2522, datetime.date(2022, 4, 20), 'P10', 61800, 9.04, 'Manesar Plant 1F'],
#  [2525, datetime.date(2022, 4, 20), 'P10', 150900, 9.05, 'Manesar Plant 1F'],
#  [2527, datetime.date(2022, 4, 20), 'P10', 61800, 9.03, 'Narsapura Plant 3F'],
#  [2531, datetime.date(2022, 4, 20), 'P10', 84100, 5.42, 'EBQ HO - Manesar'],
#  [2538, datetime.date(2022, 4, 20), 'P10', 150000, 9.15, 'Manesar Plant 1F'],
#  [2543, datetime.date(2022, 4, 20), 'P10', 81800, 4.58, 'Manesar Plant 1F'],
#  [2544, datetime.date(2022, 4, 20), 'P10', 233700, 7.14, 'Manesar Plant 1F'],
#  [2548, datetime.date(2022, 4, 20), 'P10', 233800, 7.13, 'Manesar Plant 1F'],
#  [2549, datetime.date(2022, 4, 20), 'P10', 150300, 9.08, 'Manesar Plant 1F'],
#  ...]

# %%
"""Converting time from float to mins, applied logic to check if it is greater than 9hrs & 30mins. Subtacting the 
result to get over time (minutes) converting and storing it into hrs.minutes format. """

l3=[]
for i in range(len(l2)):  
  frac, whole = math.modf(l2[i][4])
  mins=int(whole*60+frac*100)

  try:
    #1F A-Shift
    if l2[i][2]=='P10' and (dataset3.iloc[0]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[0]['Start']-3000) and '1F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[0]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #1F B-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[1]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[1]['Start']-3000) and '1F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[1]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #1F C-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[2]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[2]['Start']-3000) and '1F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[2]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #HO G-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[15]['Start']+10000)>=l2[i][3]>=(dataset3.iloc[15]['Start']-10000) and 'Head' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[15]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #2F A-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[3]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[3]['Start']-3000) and '2F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[3]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #2F B4-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[4]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[4]['Start']-3000) and '2F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[4]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #2F C-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[5]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[5]['Start']-3000) and '2F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[5]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #2F G-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[6]['Start']+10000)>=l2[i][3]>=(dataset3.iloc[6]['Start']-10000) and '2F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[6]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #3F A-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[7]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[7]['Start']-3000) and '3F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[7]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #3F B4-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[8]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[8]['Start']-3000) and '3F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[8]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #3F C-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[9]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[9]['Start']-3000) and '3F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[9]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #3F G-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[10]['Start']+10000)>=l2[i][3]>=(dataset3.iloc[10]['Start']-1000) and '3F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[10]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #4F A-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[11]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[11]['Start']-3000) and '4F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[11]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #4F B-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[12]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[12]['Start']-3000) and '4F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[12]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #4F C-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[13]['Start']+1500)>=l2[i][3]>=(dataset3.iloc[13]['Start']-3000) and '4F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[13]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

    #4F G-Shift
    elif l2[i][2]=='P10' and (dataset3.iloc[14]['Start']+10000)>=l2[i][3]>=(dataset3.iloc[14]['Start']-10000) and '4F' in l2[i][5]:
      frac1, whole1 = math.modf(dataset3.iloc[14]['Difference'])
      mins_dif=int(whole1*60+frac1*100)
      mins_dif+=30
      if mins>mins_dif:
        mins=mins-mins_dif
        hours=mins//60
        minutes=mins%60
        if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
        elif minutes%10==0:
          ot_time = float("{}.{}0".format(hours, minutes))
        else:
          ot_time = float("{}.{}".format(hours, minutes))
        l2[i]=l2[i][:-1]
        l2[i].append(ot_time)
        l3.append(l2[i])

  except:
    pass

# %%
#Removing redundant rows and storing in new data-structure
l4=[]
for i in range(len(l3)):
  if l3[i][5]>0:
    l4.append(l3[i])

# %%
for i in range(len(l4)):
  if len(l4[i])==7:
    print(l4[i][0],l4[i][1],l4[i][2],l4[i][3],l4[i][4],l4[i][5],l4[i][6])

# %%
# Converting 2d list to dataframe to apply CRUD opertations
df = pd.DataFrame(l4, columns=['E.Code','Date','IN/OUT','Time','Total Time','OT'])

# %%
df_copy=df.copy(deep=True)

# %%
#Droping an unnecesary column
df=df.drop(['IN/OUT','Time','Total Time'], axis=1)

# %%
ll1=[]
def binarySearch(arr, l, r, x):

	while l <= r:

		mid = l + (r - l) // 2

		# Check if x is present at mid
		if arr[mid] == x:
			return mid

		# If x is greater, ignore left half
		elif arr[mid] < x:
			l = mid + 1

		# If x is smaller, ignore right half
		else:
			r = mid - 1

	# If we reach here, then the element
	# was not present
	return -1


# Driver Code
arr = [int(i) for i in dataset2['E Code']]

for i in range(len(df)):
  # Function call
  result = binarySearch(arr, 0, len(arr)-1, df.iloc[i]['E.Code'])

  if result != -1:
      ll1.append([dataset2.iloc[result]['Full Name'], dataset2.iloc[result]['Designation'],dataset2.iloc[result]['Location'],dataset2.iloc[result]['Operation'],dataset2.iloc[result]['Division'],dataset2.iloc[result]['Department']])
  else:
      ll1.append(['NaN','NaN','NaN','NaN'])

# %%
# Converting 2d list to dataframe to apply CRUD opertations
dff = pd.DataFrame(ll1, columns=['Full Name','Designation','Location','Operation','Division','Department'])

# %%
df_final = pd.concat([df['E.Code'], dff, df[['Date','OT']]], axis=1)

# %%
#double shift
l_double_shift=[]
for i in range(len(df_copy)):
  if df_copy.iloc[i]['Time']>53000 and df_copy.iloc[i]['Time']<63000:
    if df_copy.iloc[i]['Total Time']>=17.50:
      l_double_shift.append([df_copy.iloc[i]['E.Code'],df_copy.iloc[i]['Date'],'A-B'])
  elif df_copy.iloc[i]['Time']>143000 and df_copy.iloc[i]['Time']<150000:
    if df_copy.iloc[i]['Total Time']>=15.50:
      l_double_shift.append([df_copy.iloc[i]['E.Code'],df_copy.iloc[i]['Date'],'B-C'])
  elif df_copy.iloc[i]['Time']>230000 and df_copy.iloc[i]['Time']<234000:
    if df_copy.iloc[i]['Total Time']>=15.50:
      l_double_shift.append([df_copy.iloc[i]['E.Code'],df_copy.iloc[i]['Date'],'C-A'])

# %%
l_double_shift=pd.DataFrame(l_double_shift,columns=['E.Code','Date','Double-Shift'])

# %%
l_double_shift2=[]
for i in range(len(l_double_shift)):
  for j in range(len(df_final)):
    if l_double_shift.iloc[i]['E.Code']==df_final.iloc[j]['E.Code'] and l_double_shift.iloc[i]['Date']==df_final.iloc[j]['Date']:
      l_double_shift2.append([df_final.iloc[j]['E.Code'],df_final.iloc[j]['Full Name'], df_final.iloc[j]['Designation'],df_final.iloc[j]['Operation'],df_final.iloc[j]['Division'],df_final.iloc[j]['Department'],df_final.iloc[j]['Date'],l_double_shift.iloc[i]['Double-Shift']])

# %%
l_double_shift2=pd.DataFrame(l_double_shift2,columns=['E.Code','Full Name','Designation','Operation','Division','Department','Date','Double-Shift'])

# %%
df_final_hr_min=df_final.copy(deep=True)
l_time1=[]
for i in df_final_hr_min.index:
      minutes, hours = math.modf(df_final_hr_min['OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time1.append(ot_time)
df_final_hr_min.drop(['OT'],axis=1)
df_final_hr_min['OT']=l_time1

# %%
""" Applying Groupby opr. to group dataframe on basis of E.Code and apply sum and count opr. to 
compute Total_OT & Total_OT_Days """

groupby_ecode_Total_OT = df.groupby(['E.Code'],as_index=False).sum()
groupby_ecode_Total_OT_Days = df.groupby(['E.Code'],as_index=False).count()
groupby_operation_sum = df_final.groupby(['Operation'],as_index=False).sum()
groupby_operation = df_final.groupby(['Operation'],as_index=False).count()
groupby_division_sum = df_final.groupby(['Division'],as_index=False).sum()
groupby_division = df_final.groupby(['Division'],as_index=False).count()
groupby_designation_sum = df_final.groupby(['Designation'],as_index=False).sum()
groupby_designation = df_final.groupby(['Designation'],as_index=False).count()
groupby_location_sum = df_final.groupby(['Location'],as_index=False).sum()
groupby_location = df_final.groupby(['Location'],as_index=False).count()
groupby_dept_sum = df_final.groupby(['Department'],as_index=False).sum()
groupby_dept = df_final.groupby(['Department'],as_index=False).count()

# %%
grp_opr = pd.DataFrame(df_final.groupby(['Operation','E.Code'],as_index=False).size())
grp_des = pd.DataFrame(df_final.groupby(['Designation','E.Code'],as_index=False).size())
grp_div = pd.DataFrame(df_final.groupby(['Division','E.Code'],as_index=False).size())
grp_loc = pd.DataFrame(df_final.groupby(['Location','E.Code'],as_index=False).size())
grp_dept = pd.DataFrame(df_final.groupby(['Department','E.Code'],as_index=False).size())

# %%
grp_opr_count=[]
for i in range(len(grp_opr)):
  grp_opr_count.append(grp_opr.iloc[i]['Operation'])

grp_des_count=[]
for i in range(len(grp_des)):
  grp_des_count.append(grp_des.iloc[i]['Designation'])

grp_div_count=[]
for i in range(len(grp_div)):
  grp_div_count.append(grp_div.iloc[i]['Division'])

grp_loc_count=[]
for i in range(len(grp_loc)):
  grp_loc_count.append(grp_loc.iloc[i]['Location'])
  
grp_dept_count=[]
for i in range(len(grp_dept)):
  grp_dept_count.append(grp_dept.iloc[i]['Department'])

# %%
import collections
# initializing dict to store frequency of each element
grp_opr_count_array = []
grp_opr_count_dict = collections.Counter(grp_opr_count)

grp_des_count_array = []
grp_des_count_dict = collections.Counter(grp_des_count)

grp_div_count_array = []
grp_div_count_dict = collections.Counter(grp_div_count)

grp_loc_count_array = []
grp_loc_count_dict = collections.Counter(grp_loc_count)

grp_dept_count_array = []
grp_dept_count_dict = collections.Counter(grp_dept_count)

# %%
grp_opr_count_array = list(grp_opr_count_dict.values())
grp_opr_count_dataframe=pd.DataFrame(grp_opr_count_array,columns=['Number of associates'])

grp_des_count_array = list(grp_des_count_dict.values())
grp_des_count_dataframe=pd.DataFrame(grp_des_count_array,columns=['Number of associates'])

grp_div_count_array = list(grp_div_count_dict.values())
grp_div_count_dataframe=pd.DataFrame(grp_div_count_array,columns=['Number of associates'])

grp_loc_count_array = list(grp_loc_count_dict.values())
grp_loc_count_dataframe=pd.DataFrame(grp_loc_count_array,columns=['Number of associates'])

grp_dept_count_array = list(grp_dept_count_dict.values())
grp_dept_count_dataframe=pd.DataFrame(grp_dept_count_array,columns=['Number of associates'])

# %%
Operation_count = pd.DataFrame(df_final.groupby(['Operation'],as_index=False).size())
Division_count = pd.DataFrame(df_final.groupby(['Division'],as_index=False).size())
Designation_count = pd.DataFrame(df_final.groupby(['Designation'],as_index=False).size())
Location_count = pd.DataFrame(df_final.groupby(['Location'],as_index=False).size())
Department_count = pd.DataFrame(df_final.groupby(['Department'],as_index=False).size())

# %%
#Converting Groupby object into DataFrame to apply CRUD opr.
df2=pd.DataFrame(groupby_ecode_Total_OT)
df3=pd.DataFrame(groupby_ecode_Total_OT_Days)
df4=pd.DataFrame(groupby_operation)
df5=pd.DataFrame(groupby_division)
df6=pd.DataFrame(groupby_operation_sum)
df7=pd.DataFrame(groupby_division_sum)
df8=pd.DataFrame(groupby_designation)
df9=pd.DataFrame(groupby_designation_sum)
df10=pd.DataFrame(groupby_location)
df11=pd.DataFrame(groupby_location_sum)
df12=pd.DataFrame(groupby_dept)
df13=pd.DataFrame(groupby_dept_sum)

# %%
df4=df4.drop(['E.Code','Full Name','Designation','Location','Division','Department','Date'], axis=1)
df5=df5.drop(['E.Code','Full Name','Designation','Location','Operation','Department','Date'], axis=1)
df8=df8.drop(['E.Code','Full Name','Location','Operation','Division','Department','Date'], axis=1)
df10=df10.drop(['E.Code','Full Name','Designation','Operation','Division','Department','Date'], axis=1)
df12=df12.drop(['E.Code','Full Name','Designation','Location','Operation','Division','Date'], axis=1)

df6=df6.drop(['E.Code'], axis=1) 
df7=df7.drop(['E.Code'], axis=1)
df9=df9.drop(['E.Code'], axis=1)
df11=df11.drop(['E.Code'], axis=1)
df13=df13.drop(['E.Code'], axis=1)

# %%
df4.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
df5.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
df8.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
df10.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
df12.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
# df6.rename(columns={'OT': 'Total OT_Days'}, inplace=True)
# df7.rename(columns={'OT': 'Total OT_Days'}, inplace=True)

# %%
l4=[]
for i in df2.index:
      frac, whole = math.modf(df2['OT'][i])
      mins=int(whole*60+frac*100)
      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      l4.append(ot_time)

# %%
llp=[]
llp2=[]
for i in df6.index:
      frac, whole = math.modf(df6['OT'][i])
      mins=int(whole*60+frac*100)
      mins2 = int(round(mins/grp_opr_count_dataframe.iloc[i]['Number of associates'],0))

      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      llp.append(ot_time)

      hours2=mins2//60
      minutes2=mins2%60
      if minutes2<10:
          ot_time2 = float("{}.0{}".format(hours2, minutes2))
      elif minutes2%10==0:
        ot_time2 = float("{}.{}0".format(hours2, minutes2))
      else:
        ot_time2 = float("{}.{}".format(hours2, minutes2))
      llp2.append(ot_time2)

# %%
lllp=[]
lllp2=[]

for i in df7.index:
      frac, whole = math.modf(df7['OT'][i])
      mins=int(whole*60+frac*100)
      mins2 = int(round(mins/grp_div_count_dataframe.iloc[i]['Number of associates'],0))

      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      lllp.append(ot_time)

      hours2=mins2//60
      minutes2=mins2%60
      if minutes2<10:
          ot_time2 = float("{}.0{}".format(hours2, minutes2))
      elif minutes2%10==0:
        ot_time2 = float("{}.{}0".format(hours2, minutes2))
      else:
        ot_time2 = float("{}.{}".format(hours2, minutes2))
      lllp2.append(ot_time2)

# %%
llllp=[]
llllp2=[]

for i in df9.index:
      frac, whole = math.modf(df9['OT'][i])
      mins=int(whole*60+frac*100)
      mins2 = int(round(mins/grp_des_count_dataframe.iloc[i]['Number of associates'],0))

      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      llllp.append(ot_time)

      hours2=mins2//60
      minutes2=mins2%60
      if minutes2<10:
          ot_time2 = float("{}.0{}".format(hours2, minutes2))
      elif minutes2%10==0:
        ot_time2 = float("{}.{}0".format(hours2, minutes2))
      else:
        ot_time2 = float("{}.{}".format(hours2, minutes2))
      llllp2.append(ot_time2)

# %%
lllllp=[]
lllllp2=[]

for i in df11.index:
      frac, whole = math.modf(df11['OT'][i])
      mins=int(whole*60+frac*100)
      mins2 = int(round(mins/grp_loc_count_dataframe.iloc[i]['Number of associates'],0))

      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      lllllp.append(ot_time)

      hours2=mins2//60
      minutes2=mins2%60
      if minutes2<10:
          ot_time2 = float("{}.0{}".format(hours2, minutes2))
      elif minutes2%10==0:
        ot_time2 = float("{}.{}0".format(hours2, minutes2))
      else:
        ot_time2 = float("{}.{}".format(hours2, minutes2))
      lllllp2.append(ot_time2)

# %%
llllllp=[]
llllllp2=[]

for i in df13.index:
      frac, whole = math.modf(df13['OT'][i])
      mins=int(whole*60+frac*100)
      mins2 = int(round(mins/grp_dept_count_dataframe.iloc[i]['Number of associates'],0))

      hours=mins//60
      minutes=mins%60
      if minutes<10:
          ot_time = float("{}.0{}".format(hours, minutes))
      elif minutes%10==0:
        ot_time = float("{}.{}0".format(hours, minutes))
      else:
        ot_time = float("{}.{}".format(hours, minutes))
      llllllp.append(ot_time)

      hours2=mins2//60
      minutes2=mins2%60
      if minutes2<10:
          ot_time2 = float("{}.0{}".format(hours2, minutes2))
      elif minutes2%10==0:
        ot_time2 = float("{}.{}0".format(hours2, minutes2))
      else:
        ot_time2 = float("{}.{}".format(hours2, minutes2))
      llllllp2.append(ot_time2)

# %%
df2['Total OT']=l4
df6['Total OT']=llp
df6['Average OT']=llp2
df7['Total OT']=lllp
df7['Average OT']=lllp2

df9['Total OT']=llllp
df9['Average OT']=llllp2

df11['Total OT']=lllllp
df11['Average OT']=lllllp2

df13['Total OT']=llllllp
df13['Average OT']=llllllp2

# %%
#Droping an unnecesary column
df3=df3.drop(['Date'], axis=1)

# %%
df2=df2.drop(['OT'], axis=1)
df6=df6.drop(['OT'], axis=1)
df7=df7.drop(['OT'], axis=1)
df9=df9.drop(['OT'], axis=1)
df11=df11.drop(['OT'], axis=1)
df13=df13.drop(['OT'], axis=1)

# %%
#Renaming Columns
#df2.rename(columns={'OT': 'Total OT'}, inplace=True)
df3.rename(columns={'OT': 'Total OT_Days'}, inplace=True)

# %%
#Creating a final dataframe (E.Code, Total OT_Days, Total OT)
# result = pd.concat([df3,df2], axis=1)
result_2 =  pd.concat([df4[['Operation','Total OT_Days']],df6['Total OT'],grp_opr_count_dataframe['Number of associates'],df6['Average OT']], axis=1)
result_3 =  pd.concat([df5,df7['Total OT'],grp_div_count_dataframe['Number of associates'],df7['Average OT']], axis=1)
result_4 =  pd.concat([df8,df9['Total OT'],grp_des_count_dataframe['Number of associates'],df9['Average OT']], axis=1)
result_5 =  pd.concat([df10,df11['Total OT'],grp_loc_count_dataframe['Number of associates'],df11['Average OT']], axis=1)
result_6 =  pd.concat([df12,df13['Total OT'],grp_dept_count_dataframe['Number of associates'],df13['Average OT']], axis=1)

# %%
result_2.rename(columns={'size': 'Count'}, inplace=True)
result_3.rename(columns={'size': 'Count'}, inplace=True)
result_4.rename(columns={'size': 'Count'}, inplace=True)
result_5.rename(columns={'size': 'Count'}, inplace=True)
result_6.rename(columns={'size': 'Count'}, inplace=True)

# %%
ll2=[]
def binarySearch(arr, l, r, x):

	while l <= r:

		mid = l + (r - l) // 2

		# Check if x is present at mid
		if arr[mid] == x:
			return mid

		# If x is greater, ignore left half
		elif arr[mid] < x:
			l = mid + 1

		# If x is smaller, ignore right half
		else:
			r = mid - 1

	# If we reach here, then the element
	# was not present
	return -1


# Driver Code
arr = [int(i) for i in dataset2['E Code']]

for i in range(len(df3)):
  # Function call
  res = binarySearch(arr, 0, len(arr)-1, df3.iloc[i]['E.Code'])

  if res != -1:
      ll2.append([dataset2.iloc[res]['Full Name'], dataset2.iloc[res]['Designation'],dataset2.iloc[res]['Operation'],dataset2.iloc[res]['Division'],dataset2.iloc[res]['Department']])
  else:
      ll2.append(['NaN','NaN','NaN','NaN'])

# %%
# Converting 2d list to dataframe to apply CRUD opertations
dfff = pd.DataFrame(ll2, columns=['Full Name','Designation','Operation','Division','Department'])

# %%
result = pd.concat([df3['E.Code'], dfff, df3['Total OT_Days'], df2['Total OT']], axis=1)

# %%
result_hr_min=result.copy(deep=True)
l_time2=[]
for i in result_hr_min.index:
      minutes, hours = math.modf(result_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time2.append(ot_time)
result_hr_min.drop(['Total OT'],axis=1)
result_hr_min['Total OT']=l_time2

# %%
l_diff=[]
if date_diff==88 or 89 or 90 or 91 or 92:
  for i in range(len(result)):
    if result.iloc[i]['Total OT']>50:
      l_diff.append([result.iloc[i]['E.Code'],result.iloc[i]['Full Name'],result.iloc[i]['Designation'],result.iloc[i]['Operation'],result.iloc[i]['Division'],result.iloc[i]['Department'],result.iloc[i]['Total OT_Days'],result.iloc[i]['Total OT']])
elif date_diff==28 or 29 or 30 or 31:
  for i in range(len(result)):
    if result.iloc[i]['Total OT']>16:
      l_diff.append([result.iloc[i]['E.Code'],result.iloc[i]['Full Name'],result.iloc[i]['Designation'],result.iloc[i]['Operation'],result.iloc[i]['Division'],result.iloc[i]['Department'],result.iloc[i]['Total OT_Days'],result.iloc[i]['Total OT']])
else:
  for i in range(len(result)):
    if result.iloc[i]['Total OT']>((16/30)*date_diff):
      l_diff.append([result.iloc[i]['E.Code'],result.iloc[i]['Full Name'],result.iloc[i]['Designation'],result.iloc[i]['Operation'],result.iloc[i]['Division'],result.iloc[i]['Department'],result.iloc[i]['Total OT_Days'],result.iloc[i]['Total OT']])

# %%
l_diff = pd.DataFrame(l_diff, columns=['E.Code','Full Name','Designation','Operation','Division','Department','Total OT_Days','Total OT'])

# %%
l_diff_hr_min=l_diff.copy(deep=True)
l_time3=[]
for i in l_diff_hr_min.index:
      minutes, hours = math.modf(l_diff_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time3.append(ot_time)
l_diff_hr_min.drop(['Total OT'],axis=1)
l_diff_hr_min['Total OT']=l_time3

# %%
# Sorting dataframe in descending order on basis of Total OT_Days (User can get top x employees on basis of Total OT_Days)
cont2=result.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont2_hr_min=cont2.copy(deep=True)
l_time4=[]
for i in cont2_hr_min.index:
      minutes, hours = math.modf(cont2_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time4.append(ot_time)
cont2_hr_min.drop(['Total OT'],axis=1)
cont2_hr_min['Total OT']=l_time4

# %%
cont2_consecutive=[]
i=0
while cont2.iloc[i]['Total OT_Days']>=10:
  cont2_consecutive.append(cont2.iloc[i]['E.Code'])
  i+=1

# %%
cont2_consecutive
l_con=[]
for x in cont2_consecutive:
  for j in range(len(df_final)):
    if x == df_final.iloc[j]['E.Code']:
      l_con.append([x, df_final.iloc[j]['Date']])

# %%
l_10con=[]
for j in cont2_consecutive:
  p,c=0,1
  for i in range(len(l_con)):
    p=i+1
    if p <= len(l_con)-1:
      if j==l_con[i][0] and j==l_con[p][0]:
          if l_con[i][1].day-l_con[p][1].day==-1:
            c+=1
          elif l_con[i][1].weekday()==4:
            if l_con[i][1].day-l_con[p][1].day==-3:
              c+=1
  if c>=10:
    l_10con.append(j)

# %%
l_10_final=[]
# result_10day=result
# result_10day=result_10day.drop(['Total OT_Days','Total OT'],axis=1)
j=0
while j<len(l_10con):
  for i in range(len(result)):
    if result.iloc[i]['E.Code']== l_10con[j]:
      l_10_final.append([result.iloc[i]['E.Code'],result.iloc[i]['Full Name'],result.iloc[i]['Designation'],result.iloc[i]['Operation'],result.iloc[i]['Division'],result.iloc[i]['Department']])
      break;
  j+=1

dfff_10 = pd.DataFrame(l_10_final, columns=['E.Code','Full Name','Designation','Operation','Division','Department'])

# %%
# Sorting dataframe in descending order on basis of Total OT (User can get top x employees on basis of Total OT)
cont3=result.sort_values(by=['Total OT'], ascending=False)

# %%
cont3_hr_min=cont3.copy(deep=True)
l_time5=[]
for i in cont3_hr_min.index:
      minutes, hours = math.modf(cont3_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time5.append(ot_time)
cont3_hr_min.drop(['Total OT'],axis=1)
cont3_hr_min['Total OT']=l_time5

# %%
cont4=result_2.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont4_hr_min=cont4.copy(deep=True)
l_time6=[]
l_time6n=[]
for i in cont4_hr_min.index:
      minutes, hours = math.modf(cont4_hr_min['Total OT'][i])
      minutesn, hoursn = math.modf(cont4_hr_min['Average OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time6.append(ot_time)
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time6n.append(ot_timen)
cont4_hr_min.drop(['Total OT'],axis=1)
cont4_hr_min['Total OT']=l_time6
cont4_hr_min.drop(['Average OT'],axis=1)
cont4_hr_min['Average OT']=l_time6n

# %%
cont5=result_2.sort_values(by=['Total OT'], ascending=False)

# %%
cont5_hr_min=cont5.copy(deep=True)
l_time7=[]
l_time7n=[]
for i in cont5_hr_min.index:
      minutes, hours = math.modf(cont5_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time7.append(ot_time)
      minutesn, hoursn = math.modf(cont5_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time7n.append(ot_timen)
cont5_hr_min.drop(['Total OT'],axis=1)
cont5_hr_min['Total OT']=l_time7
cont5_hr_min.drop(['Average OT'],axis=1)
cont5_hr_min['Average OT']=l_time7n

# %%
cont6=result_3.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont6_hr_min=cont6.copy(deep=True)
l_time8=[]
l_time8n=[]
for i in cont6_hr_min.index:
      minutes, hours = math.modf(cont6_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time8.append(ot_time)

      minutesn, hoursn = math.modf(cont6_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time8n.append(ot_timen)
cont6_hr_min.drop(['Total OT'],axis=1)
cont6_hr_min['Total OT']=l_time8

cont6_hr_min.drop(['Average OT'],axis=1)
cont6_hr_min['Average OT']=l_time8n

# %%
cont7=result_3.sort_values(by=['Total OT'], ascending=False)

# %%
cont7_hr_min=cont7.copy(deep=True)
l_time9=[]
l_time9n=[]

for i in cont7_hr_min.index:
      minutes, hours = math.modf(cont7_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time9.append(ot_time)

      minutesn, hoursn = math.modf(cont7_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time9n.append(ot_timen)
cont7_hr_min.drop(['Total OT'],axis=1)
cont7_hr_min['Total OT']=l_time9

cont7_hr_min.drop(['Average OT'],axis=1)
cont7_hr_min['Average OT']=l_time9n

# %%
cont8=result_4.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont8_hr_min=cont8.copy(deep=True)
l_time10=[]
l_time10n=[]

for i in cont8_hr_min.index:
      minutes, hours = math.modf(cont8_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time10.append(ot_time)

      minutesn, hoursn = math.modf(cont8_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time10n.append(ot_timen)
cont8_hr_min.drop(['Total OT'],axis=1)
cont8_hr_min['Total OT']=l_time10

cont8_hr_min.drop(['Average OT'],axis=1)
cont8_hr_min['Average OT']=l_time10n

# %%
cont9=result_4.sort_values(by=['Total OT'], ascending=False)

# %%
cont9_hr_min=cont9.copy(deep=True)
l_time11=[]
l_time11n=[]

for i in cont9_hr_min.index:
      minutes, hours = math.modf(cont9_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time11.append(ot_time)

      minutesn, hoursn = math.modf(cont9_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time11n.append(ot_timen)
cont9_hr_min.drop(['Total OT'],axis=1)
cont9_hr_min['Total OT']=l_time11

cont9_hr_min.drop(['Average OT'],axis=1)
cont9_hr_min['Average OT']=l_time11n

# %%
cont11=result_5.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont11_hr_min=cont11.copy(deep=True)
l_time13=[]
l_time13n=[]

for i in cont11_hr_min.index:
      minutes, hours = math.modf(cont11_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time13.append(ot_time)

      minutesn, hoursn = math.modf(cont11_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time13n.append(ot_timen)
cont11_hr_min.drop(['Total OT'],axis=1)
cont11_hr_min['Total OT']=l_time13

cont11_hr_min.drop(['Average OT'],axis=1)
cont11_hr_min['Average OT']=l_time13n

# %%
# Sorting dataframe in descending order on basis of Total OT (User can get top x employees on basis of Total OT)
cont10=result_5.sort_values(by=['Total OT'], ascending=False)

# %%
cont10_hr_min=cont10.copy(deep=True)
l_time12=[]
l_time12n=[]

for i in cont10_hr_min.index:
      minutes, hours = math.modf(cont10_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time12.append(ot_time)

      minutesn, hoursn = math.modf(cont10_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time12n.append(ot_timen)
cont10_hr_min.drop(['Total OT'],axis=1)
cont10_hr_min['Total OT']=l_time12

cont10_hr_min.drop(['Average OT'],axis=1)
cont10_hr_min['Average OT']=l_time12n

# %%
cont13=result_6.sort_values(by=['Total OT_Days'], ascending=False)

# %%
cont13_hr_min=cont13.copy(deep=True)
l_time15=[]
l_time15n=[]

for i in cont13_hr_min.index:
      minutes, hours = math.modf(cont13_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time15.append(ot_time)

      minutesn, hoursn = math.modf(cont13_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time15n.append(ot_timen)
cont13_hr_min.drop(['Total OT'],axis=1)
cont13_hr_min['Total OT']=l_time15

cont13_hr_min.drop(['Average OT'],axis=1)
cont13_hr_min['Average OT']=l_time15n

# %%
# Sorting dataframe in descending order on basis of Total OT (User can get top x employees on basis of Total OT)
cont12=result_6.sort_values(by=['Total OT'], ascending=False)

# %%
cont12_hr_min=cont12.copy(deep=True)
l_time14=[]
l_time14n=[]

for i in cont12_hr_min.index:
      minutes, hours = math.modf(cont12_hr_min['Total OT'][i])
      minutes*=100
      ot_time = "{:.0f} Hr {:.0f} Min".format(hours, minutes)
      l_time14.append(ot_time)

      minutesn, hoursn = math.modf(cont12_hr_min['Average OT'][i])
      minutesn*=100
      ot_timen = "{:.0f} Hr {:.0f} Min".format(hoursn, minutesn)
      l_time14n.append(ot_timen)
cont12_hr_min.drop(['Total OT'],axis=1)
cont12_hr_min['Total OT']=l_time14

cont12_hr_min.drop(['Average OT'],axis=1)
cont12_hr_min['Average OT']=l_time14n

# %%
# !pip install xlsxwriter

# %%
from openpyxl import Workbook
import xlsxwriter
import os

workbook = xlsxwriter.Workbook(r'OT_Analysis.xlsx')
with pd.ExcelWriter(r'OT_Analysis.xlsx') as writer:
#writer = r"C:\Users\Kartikey\Desktop\shorttt.xlsx"
# write dataframe to excel
    df_final_hr_min.to_excel(writer,sheet_name='OT')
    result_hr_min.to_excel(writer,sheet_name='Total_OT')
    cont2_hr_min.to_excel(writer,sheet_name='Highest_Total_OT_Days')
    cont3_hr_min.to_excel(writer,sheet_name='Highest_Total_OT')
    l_diff_hr_min.to_excel(writer,sheet_name='Exceeding OT Limit')
    dfff_10.to_excel(writer,sheet_name='Exceeding 10 cons. OT days')
    l_double_shift2.to_excel(writer,sheet_name='Double shift')
    cont4_hr_min.to_excel(writer,sheet_name='Operation_Highest_Total_OT_Days')
    cont5_hr_min.to_excel(writer,sheet_name='Operation_Highest_Total_OT')
    cont6_hr_min.to_excel(writer,sheet_name='Division_Highest_Total_OT_Days')
    cont7_hr_min.to_excel(writer,sheet_name='Division_Highest_Total_OT')
    cont8_hr_min.to_excel(writer,sheet_name='Desig_Highest_Total_OT_Days')
    cont9_hr_min.to_excel(writer,sheet_name='Desig_Highest_Total_OT')
    cont11_hr_min.to_excel(writer,sheet_name='Location_Highest_Total_OT_Days')
    cont10_hr_min.to_excel(writer,sheet_name='Location_Highest_Total_OT')
    cont13_hr_min.to_excel(writer,sheet_name='Dept_Highest_Total_OT_Days')
    cont12_hr_min.to_excel(writer,sheet_name='Dept_Highest_Total_OT')
